# %% [markdown]
# # Named Entity Recognition NER using spaCy - Extracting Subject Verb Action
#
# ## [Link to my Youtube Video Explaining this whole Notebook](https://www.youtube.com/watch?v=TxTxWAohW7E&list=PLxqBkZuBynVTn2lkHNAcw6lgm1MD5QiMK&index=5)
#
# [![Imgur](https://imgur.com/s0Oc4p5.png)](https://www.youtube.com/watch?v=TxTxWAohW7E&list=PLxqBkZuBynVTn2lkHNAcw6lgm1MD5QiMK&index=5)

# %% [markdown]
# ## First What is BERT?
#
# BERT stands for Bidirectional Encoder Representations from Transformers. The name itself gives us several clues to what BERT is all about.
#
# BERT architecture consists of several Transformer encoders stacked together. Each Transformer encoder encapsulates two sub-layers: a self-attention layer and a feed-forward layer.
#
# ### There are two different BERT models:
#
# - BERT base, which is a BERT model consists of 12 layers of Transformer encoder, 12 attention heads, 768 hidden size, and 110M parameters.
#
# - BERT large, which is a BERT model consists of 24 layers of Transformer encoder,16 attention heads, 1024 hidden size, and 340 parameters.
#
#
#
# BERT Input and Output
# BERT model expects a sequence of tokens (words) as an input. In each sequence of tokens, there are two special tokens that BERT would expect as an input:
#
# - [CLS]: This is the first token of every sequence, which stands for classification token.
# - [SEP]: This is the token that makes BERT know which token belongs to which sequence. This special token is mainly important for a next sentence prediction task or question-answering task. If we only have one sequence, then this token will be appended to the end of the sequence.
#
#
# It is also important to note that the maximum size of tokens that can be fed into BERT model is 512. If the tokens in a sequence are less than 512, we can use padding to fill the unused token slots with [PAD] token. If the tokens in a sequence are longer than 512, then we need to do a truncation.
#
# And that’s all that BERT expects as input.
#
# BERT model then will output an embedding vector of size 768 in each of the tokens. We can use these vectors as an input for different kinds of NLP applications, whether it is text classification, next sentence prediction, Named-Entity-Recognition (NER), or question-answering.
#
#
# ------------
#
# **For a text classification task**, we focus our attention on the embedding vector output from the special [CLS] token. This means that we’re going to use the embedding vector of size 768 from [CLS] token as an input for our classifier, which then will output a vector of size the number of classes in our classification task.
#
# -----------------------
#
# ![Imgur](https://imgur.com/NpeB9vb.png)
#
# -------------------------

# %%
import pandas as pd

# %%
ROOT_DIR = '../../input/' # Local Machine

# ROOT_DIR = '../input/all-the-news/' # Kaggle


# print(os.listdir('../input/all-the-news/'))

# %%
# path = "all-the-news/"
df = pd.read_csv(ROOT_DIR + "articles1.csv")

# %%
df.shape
# Out:
# (50000, 10)

# %%
df.head()
# Out:
#    Unnamed: 0     id                                              title  \
# 0           0  17283  House Republicans Fret About Winning Their Hea...
# 1           1  17284  Rift Between Officers and Residents as Killing...
# 2           2  17285  Tyrus Wong, ‘Bambi’ Artist Thwarted by Racial ...
# 3           3  17286  Among Deaths in 2016, a Heavy Toll in Pop Musi...
# 4           4  17287  Kim Jong-un Says North Korea Is Preparing to T...
#
#       publication                         author        date    year  month  \
# 0  New York Times                     Carl Hulse  2016-12-31  2016.0   12.0
# 1  New York Times  Benjamin Mueller and Al Baker  2017-06-19  2017.0    6.0
# 2  New York Times                   Margalit Fox  2017-01-06  2017.0    1.0
# 3  New York Times               William McDonald  2017-04-10  2017.0    4.0
# 4  New York Times                  Choe Sang-Hun  2017-01-02  2017.0    1.0
#
#    url                                            content
# 0  NaN  WASHINGTON  —   Congressional Republicans have...
# 1  NaN  After the bullet shells get counted, the blood...
# 2  NaN  When Walt Disney’s “Bambi” opened in 1942, cri...
# 3  NaN  Death may be the great equalizer, but it isn’t...
# 4  NaN  SEOUL, South Korea  —   North Korea’s leader, ...

# %%
sources = df["publication"].unique()
print(sources)
# Out:
# ['New York Times' 'Breitbart' 'CNN' 'Business Insider' 'Atlantic']

# %%
condition = df["publication"].isin(["New York Times"])

content_df = df.loc[condition, :]["content"][:100]

content_df.shape
# Out:
# (100,)

# %%
content_df.head()
# Out:
# 0    WASHINGTON  —   Congressional Republicans have...
# 1    After the bullet shells get counted, the blood...
# 2    When Walt Disney’s “Bambi” opened in 1942, cri...
# 3    Death may be the great equalizer, but it isn’t...
# 4    SEOUL, South Korea  —   North Korea’s leader, ...
# Name: content, dtype: object

# %%
for article in content_df[:2]:
    print(article)

# %%
import spacy

nlp = spacy.load('en_core_web_sm')

text = "He would not tell the police what he had learned"

doc = nlp(text)

for token in doc:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_, token.shape_, token.is_alpha, token.is_stop  )
# Out:
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.6) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
# /home/paul/.local/lib/python3.9/site-packages/spacy/util.py:837: UserWarning: [W095] Model 'en_core_web_sm' (3.2.0) was trained with spaCy v3.2 and may not be 100% compatible with the current version (3.3.1). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# He he PRON PRP nsubj Xx True True
# would would AUX MD aux xxxx True True
# not not PART RB neg xxx True True
# tell tell VERB VB ROOT xxxx True False
# the the DET DT det xxx True True
# police police NOUN NNS dobj xxxx True False
# what what PRON WP dobj xxxx True True
# he he PRON PRP nsubj xx True True
# had have AUX VBD aux xxx True True
# learned learn VERB VBN ccomp xxxx True False

# %% [markdown]
# ### In below the named_entities variable should show me a dict structure like below
#
# ```
# {
# 'GPE': {'WASHINGTON': 1,
#     'Obama': 1,
#     'the District of Columbia Circuit': 1,
#     'Manhattan': 13,
#     'New York City': 3,
#     'Bronx': 19 },
#
# 'NORP': {'Republicans': 15,
#     'Americans': 1,
#     'Republican': 2,
#     'Hispanic': 1,}
# ```

# %%
def return_entities_and_processed_docs(data_frame):
    """
    Extracts named entities from a DataFrame and returns them along with the processed docs.

    Args:
        data_frame (DataFrame): The DataFrame from which to extract named entities.

    Returns:
        dict: A dictionary mapping entity types to a dictionary of entity names to counts.
        list: A list of processed docs.
    """
    # Initialize the dictionary to hold named entities
    named_entities = {}
    # Initialize the list to hold processed docs
    processed_docs = []
    
    # Process each item in the DataFrame
    for item in data_frame:
        # Process the item with a language model
        doc = nlp(item)
        # Add the processed doc to the list
        processed_docs.append(doc)
        
        # For each named entity in the doc...
        for ent in doc.ents:
            # Extract the entity text (e.g., 'WASHINGTON')
            entity_text = ent.text
            # Extract the entity type (e.g., 'GPE')
            entity_type = str(ent.label_)
            # Initialize a dictionary to hold the current entities
            current_ents = {}
            
            # If the entity type is already in the named entities dictionary...
            if entity_type in named_entities.keys():
                # Get the dictionary of entity names to counts
                current_ents = named_entities.get(entity_type)
                
            # Increment the count for the entity name
            # This will add 1 to the count in the inner dictionary
            current_ents[entity_text] = current_ents.get(entity_text, 0) + 1
            
            # Update the inner dictionary for the entity type
            named_entities[entity_type] = current_ents

    # Return the named entities and the processed docs
    return named_entities, processed_docs


named_entities, processed_docs = return_entities_and_processed_docs(content_df)

# %%
named_entities
# Out:
# {'GPE': {'WASHINGTON': 18,
#   'Obama': 2,
#   'the District of Columbia Circuit': 1,
#   'Manhattan': 30,
#   'New York City': 13,
#   'Bronx': 26,
#   'Upper Manhattan': 2,
#   'Lower Manhattan': 2,
#   'the United States': 81,
#   'St. Mary’s Park': 1,
#   'New York': 38,
#   'Mott Haven': 1,
#   'Brooklyn': 18,
#   'Queens': 10,
#   'Staten Island': 4,
#   'Washington Heights': 1,
#   'Gramercy Park': 1,
#   'the City of New York': 1,
#   'America': 31,
#   'Hollywood': 7,
#   'California': 21,
#   'San Francisco': 7,
#   'San Francisco Bay': 1,
#   'Angel Island': 2,
#   'Guangdong Province': 1,
#   'United States': 20,
#   'Attuned': 1,
#   'Sacramento': 2,
#   'Los Angeles': 10,
#   'Pasadena': 1,
#   'Sunland': 2,
#   'Calif.': 11,
#   'Minneapolis': 3,
#   'Eagles': 1,
#   'Saskatchewan': 1,
#   'Tennessee': 4,
#   'New York Giant': 1,
#   'Texas': 6,
#   'Waco': 1,
#   'Tex.': 4,
#   'Rwanda': 1,
#   'Bosnia': 1,
#   'Israel': 16,
#   'Poland': 1,
#   'Vera Rubin': 1,
#   'SEOUL': 1,
#   'South Korea': 7,
#   'North Korea’s': 2,
#   'North Korea': 13,
#   'Cheong': 1,
#   'Rodong': 1,
#   'Japan': 5,
#   'Guam': 1,
#   'LONDON': 2,
#   'Norfolk': 1,
#   'England': 4,
#   'Thailand': 1,
#   'Britain': 5,
#   'Taiwan': 13,
#   'China': 61,
#   'Beijing': 15,
#   'Taipei': 1,
#   'The United States': 6,
#   'Washington': 48,
#   'Houston': 6,
#   'Versailles': 1,
#   'Ky.': 2,
#   'Charlotte': 2,
#   'Laconia, N. H.': 1,
#   'Williamsburg': 1,
#   'Va.': 2,
#   'Starz': 1,
#   'La Jolla': 1,
#   'San Diego': 1,
#   'Polihale Beach': 1,
#   'Kauai': 1,
#   'Hawaii': 3,
#   'Palm Springs': 2,
#   'New Hampshire': 1,
#   'Puerto Rico': 2,
#   'New York State': 2,
#   'Ohio': 4,
#   'Iowa': 5,
#   'Paris': 11,
#   'North Dakota': 1,
#   'Rhode Island': 1,
#   'La Porte': 1,
#   'WEST PALM BEACH': 1,
#   'Fla.': 2,
#   'Palm Beach': 3,
#   'Crawford': 1,
#   'Kennebunkport': 1,
#   'Florida': 6,
#   'Midtown Manhattan': 2,
#   'Ireland': 3,
#   'Mexico': 21,
#   'Melania': 2,
#   'Maryland': 2,
#   'Adorama': 1,
#   'Zoomin': 1,
#   'PhotoBarn': 3,
#   'Tokyo': 4,
#   'Irvine': 1,
#   'Minn.': 1,
#   'New York’s': 2,
#   'Boston': 2,
#   'Sumana': 1,
#   'Harihareswara': 1,
#   'Astoria': 1,
#   'East Harlem': 1,
#   'Braithophone': 1,
#   'Charleston': 4,
#   'Indiana': 5,
#   'Faretta': 1,
#   'India': 10,
#   'New Delhi': 4,
#   'Gujarat': 1,
#   'East Delhi': 1,
#   'Baghdad': 5,
#   'France': 13,
#   'Iraq': 28,
#   'ISIL': 2,
#   'Mosul': 3,
#   'Sadr City': 1,
#   'Moktada': 1,
#   'The United States State Department': 1,
#   'Syria': 24,
#   'SYDNEY': 1,
#   'Australia': 2,
#   'Melbourne': 2,
#   'Victoria': 1,
#   'Port Phillip': 1,
#   'Detroit': 2,
#   'the N. F. C. East': 1,
#   'Dallas': 5,
#   'Atlanta': 4,
#   'the N. F. C.': 3,
#   'Oakland': 2,
#   'Miami': 7,
#   'Pittsburgh': 2,
#   'Kansas City': 1,
#   'Philadelphia': 5,
#   'New Orleans': 1,
#   'Indianapolis': 3,
#   'Stella Bulochnikov': 1,
#   'Grammys': 1,
#   'PARIS': 2,
#   'Iconem': 1,
#   'Khorsabad': 1,
#   'Damascus': 8,
#   'Yemen': 1,
#   'Mesopotamia': 1,
#   'London': 10,
#   'Tatjana': 2,
#   'Cindy': 1,
#   'Wham': 1,
#   'Boy Bar': 1,
#   'Kentucky': 3,
#   'Wisconsin': 1,
#   'Alabama': 3,
#   'Russia': 50,
#   'Oklahoma': 2,
#   'Colorado': 2,
#   'Istanbul': 8,
#   'Turkey': 40,
#   'South Korea’s': 1,
#   'Denmark': 4,
#   'Delhi': 1,
#   'Mogadishu': 1,
#   'Somalia': 1,
#   'Brazil': 4,
#   'Pakistan': 5,
#   'Sichuan Province': 2,
#   'Yan’an': 1,
#   'Myanmar': 1,
#   'Germany': 8,
#   'Connecticut': 1,
#   'the United States Central Command': 1,
#   'Vietnam': 3,
#   'Vietcong': 1,
#   'Survival': 1,
#   'Korea': 1,
#   'Afghanistan': 42,
#   'Cuba': 1,
#   'Kyrgyzstan': 3,
#   'Interfax': 1,
#   'Ankara': 1,
#   'Libya': 1,
#   'Illinois': 4,
#   'Chicago': 5,
#   'Nuristan': 1,
#   'Kabul': 4,
#   'Kandahar': 2,
#   'Karzai': 1,
#   'Kunduz': 1,
#   'Bagram': 1,
#   'North Africa': 1,
#   'West Point': 1,
#   'Warsaw': 1,
#   'Aunt Joan': 1,
#   'West Bank': 3,
#   'East Jerusalem': 1,
#   'Italy': 7,
#   'Cancun': 1,
#   'Calgary': 1,
#   'Alberta': 2,
#   'Canada': 13,
#   'Toronto': 3,
#   'Slovenia': 2,
#   'São Paulo': 2,
#   'Sérgio Fontes': 1,
#   'Manaus as': 1,
#   'the United States Air Force': 1,
#   'Hawthorne': 1,
#   'New Jersey': 7,
#   'Livingston': 1,
#   'Paramus': 1,
#   'Midwood': 1,
#   'Long Island': 1,
#   'Pennsylvania': 2,
#   'Jordan': 1,
#   'Mamaroneck': 1,
#   'Claremont': 1,
#   'Alaska': 3,
#   'Berkeley': 1,
#   'Mindanao': 1,
#   'Philippines': 7,
#   'Elmhurst': 2,
#   'the Filipino Consulate': 1,
#   'Neediest Cases': 1,
#   'Virginia': 2,
#   'South Carolina': 3,
#   'New Mexico': 1,
#   'North Carolina': 3,
#   'Azerbaijan': 1,
#   'Michigan': 5,
#   'Hell': 1,
#   'Mich.': 3,
#   'Wyoming': 2,
#   'Flat Rock': 1,
#   'Utah': 1,
#   'Coahuila': 1,
#   'Arizona': 3,
#   'Flint': 1,
#   'Vermont': 3,
#   'San Bernardino': 2,
#   'LOS ANGELES': 1,
#   'Hebron': 3,
#   'Tel Aviv': 1,
#   'Azaria': 1,
#   'Murdochs': 3,
#   'Shanghai': 1,
#   'the Faroe Islands': 1,
#   'Henan Province': 1,
#   'Cisco': 1,
#   '’s': 1,
#   'Panzhihua': 2,
#   'Montauk': 1,
#   'Rockport': 1,
#   'Mass.': 2,
#   'Bay Ridge': 1,
#   'Melina': 1,
#   'Somerville': 1,
#   'Portsmouth': 1,
#   'Rafael': 2,
#   'Neediest': 1,
#   'Georgia': 3,
#   'Oregon': 1,
#   'West Virginia': 1,
#   'the District of Columbia': 1,
#   'Tracy': 1,
#   'Belmont': 1,
#   'Riga': 1,
#   'Latvia': 1,
#   'Moscow': 4,
#   'Soho Rooms': 1,
#   'Kiev': 1,
#   'Ukraine': 8,
#   'Alibaba': 1,
#   'New York City bar association': 1,
#   'CHARLESTON': 1,
#   'Charleston County': 1,
#   'Seattle': 1,
#   'Uzbekistan': 2,
#   'stymie': 1,
#   'the Ottoman Empire': 1,
#   'Lebanon': 2,
#   'Geneva': 2,
#   'Astana': 1,
#   'Kazakhstan': 1,
#   'Hong Kong': 3,
#   'British Columbia': 3,
#   'Vancouver Island': 3,
#   'Port Hardy': 1,
#   'Kwakiutl': 2,
#   'Vancouver Island’s': 1,
#   'Kingston': 3,
#   'Ottawa': 4,
#   'Burbank': 1,
#   'Whitehorse': 1,
#   'Dawson City': 1,
#   'Dawson': 1,
#   'Prussia': 1,
#   'Niagara': 2,
#   'Ontario': 1,
#   'Avondale Dairy': 1,
#   'Herman Melville': 1,
#   'Quebec': 2,
#   'Mystic': 1,
#   'j’avais': 1,
#   'Memphrémagog': 1,
#   'Montreal': 2,
#   'Tofino': 1,
#   'Berlin': 1,
#   'Milwaukee': 1,
#   'Monterey': 1,
#   'Mustique': 1,
#   'San   ': 1,
#   'Austria': 1,
#   'Vienna': 2,
#   'Salzburg': 1,
#   'Hamburg': 1,
#   'West Palm Beach': 1,
#   'Orlando': 2,
#   'Central Fare': 1,
#   'Switzerland': 1,
#   'Zurich': 1,
#   'Rhine': 1,
#   'the Northwest Territories': 1,
#   'Falsettos': 1,
#   'Ruben': 1,
#   'Glocca': 1,
#   'Highwaymen': 1,
#   'Mag': 1,
#   'New York City’s': 2,
#   'Puebla city': 1,
#   'Mexico City': 1,
#   'Puebla state': 1,
#   'Puebla': 4,
#   'the R. C. S.': 2,
#   'Colombia': 1,
#   'Honduras': 1,
#   'Ethiopia': 2,
#   'Bahrain': 3,
#   'Morocco': 3,
#   'Egypt': 3,
#   'Saudi Arabia': 1,
#   'Sudan': 5,
#   'United   ': 1,
#   'Reddit': 1,
#   'P4ssword': 1,
#   'Ecuador': 1,
#   'the R. C. S. Three': 1,
#   'Quito': 1,
#   'Milan': 3,
#   'Transylvania': 1,
#   'Iran': 4,
#   'Madrid': 1,
#   'Singapore': 1,
#   'the United Arab Emirates': 1,
#   'Alexandria': 1,
#   'Amsterdam': 1,
#   'Jalisco': 1,
#   'Moreno Valle’s': 1,
#   'Reston': 1,
#   'Fort Lauderdale': 1,
#   'Montana': 2,
#   'Baltimore': 1,
#   'Cincinnati': 1,
#   'St. Clair': 1,
#   'Mo.': 1,
#   'Inez': 1,
#   'Foxconn': 1,
#   '0': 1,
#   'Haiti': 1,
#   'West Africa': 1,
#   'Kidapawan City': 1,
#   'Manila': 1,
#   'Las Vegas': 1,
#   'Southampton': 1,
#   'Wiltshire': 1,
#   'Belfast': 1,
#   'Apulia': 2,
#   'Penelope': 3,
#   'Echo Park': 1,
#   'Netflix': 1,
#   'Horst': 1,
#   'Missouri': 1,
#   'Arkansas': 1,
#   'Maine': 1,
#   'Fort Wayne': 1,
#   'Ind.': 1,
#   'the D. N. C. ’s': 1,
#   'Estonia': 1,
#   'Illuminati': 1,
#   'Cleveland': 1,
#   'Hangzhou': 1,
#   'Gambia': 1,
#   'Argentina': 3,
#   'Tunisia': 2,
#   'Bolivia': 1,
#   'Uganda': 2,
#   'Lima': 1,
#   'Peru': 1,
#   'Costa Rica': 1,
#   'the Czech Republic': 1,
#   'Prague': 1,
#   'Brussels': 1,
#   'Belgium': 1,
#   'Algeria': 1,
#   'Finland': 1,
#   'Ala.': 1,
#   'the United States of America': 1,
#   'Birmingham': 2,
#   'Mobile': 1,
#   'Kenmore': 1,
#   'New Jersey Transit': 1,
#   'Hoboken': 1,
#   'DETROIT': 1,
#   'Silverado': 1,
#   'Rochester': 1,
#   'Johnson City': 1,
#   'Binghamton': 1,
#   'Wayne': 1},
#  'NORP': {'Republicans': 138,
#   'Americans': 26,
#   'Republican': 67,
#   'Hispanic': 3,
#   'Chinese': 48,
#   'scan': 3,
#   'Modernist': 1,
#   'Asian': 1,
#   'Asians': 1,
#   'Austrian': 1,
#   'Japanese': 3,
#   'American': 136,
#   'Cuban': 2,
#   'Egyptian': 4,
#   'French': 17,
#   'Iranian': 2,
#   'Nazis': 1,
#   'Communists': 1,
#   'Latin': 2,
#   'Dutch': 1,
#   'Nazi': 1,
#   'South Korean': 1,
#   'Taiwanese': 1,
#   'obese': 2,
#   'Nico': 1,
#   'German': 6,
#   'Manish': 1,
#   'Mazzy Star': 1,
#   'Hawaiian': 1,
#   'Roman Catholic': 1,
#   'Catholic': 2,
#   'Norwegian': 1,
#   'Petra': 5,
#   'Democrat': 23,
#   'British': 7,
#   'Jews': 2,
#   'Democratic': 31,
#   'Swiss': 1,
#   'Snapfish': 1,
#   'Zines': 1,
#   'PhotoScan': 3,
#   'New Yorkers': 3,
#   'South Asian': 1,
#   'Jewish': 7,
#   'Indians': 5,
#   'Indian': 3,
#   'Iraqi': 8,
#   'Shiite': 2,
#   'Sunni': 1,
#   'Kurdish': 4,
#   'Iraqis': 2,
#   'Melbournians': 1,
#   'Texans': 3,
#   'Panthers': 1,
#   'Islamists': 2,
#   'Syrian': 14,
#   'Islamist': 3,
#   'Christian': 1,
#   'jihadists': 4,
#   'Assyrian': 1,
#   'Saudi': 1,
#   'Sorbonne': 1,
#   'Democrats': 60,
#   'Russian': 59,
#   'Trump': 1,
#   'Russians': 24,
#   'Congressional Democrats': 1,
#   'Turkish': 19,
#   'Islamic': 3,
#   'European': 5,
#   'Muslims': 3,
#   'African': 2,
#   'Mongolian': 1,
#   'Tibetan': 1,
#   'Arab': 3,
#   'Marines': 2,
#   'Marine': 4,
#   'Christians': 1,
#   'jihadist': 3,
#   'Afghan': 4,
#   'Afghans': 1,
#   'Hanukkah': 1,
#   'Israeli': 20,
#   'Brazilian': 2,
#   'Compaj': 1,
#   'Portuguese': 2,
#   'Riverdale': 1,
#   'Orthodox': 4,
#   'Cobras': 1,
#   'Hasidic': 1,
#   'Islanders': 1,
#   'Filipino': 1,
#   'Palestinian': 4,
#   'Irish': 5,
#   'Mexican': 13,
#   'Conservatives': 1,
#   'Israelis': 2,
#   'Palestinians': 2,
#   'Spanish': 4,
#   'Scottish': 1,
#   'English': 1,
#   'Evergrande': 1,
#   'South American': 1,
#   'Jacksonians': 1,
#   'Populist': 1,
#   'Populists': 2,
#   'Dems': 2,
#   'Muslim': 2,
#   'Turks': 3,
#   'Syrians': 1,
#   'Canadian': 3,
#   'Victorian': 2,
#   'Catholics': 1,
#   'dans': 7,
#   'Irlandais': 1,
#   'Baroque': 1,
#   'Venezuelan': 1,
#   'Tohoku': 1,
#   'Chekhovian': 1,
#   'Australian': 1,
#   'Italian': 9,
#   'North Korean': 1,
#   'Western': 1,
#   'Middle Eastern': 1,
#   'Libyan': 1,
#   'Latin American': 1,
#   'North American': 1,
#   'Uzbek': 1,
#   'iTunes': 1,
#   'Philippine': 1,
#   'Experian': 2,
#   'Harland': 2,
#   'Roman': 1,
#   'Feudi': 1,
#   'dramedy': 1,
#   'Soviet': 2,
#   'Romanian': 5,
#   'North Koreans': 1,
#   'Iranians': 1,
#   'Mormon Tabernacle Choir': 1},
#  'PERSON': {'Obama': 114,
#   'Donald J. Trump’s': 4,
#   'Phillip J. Blando': 1,
#   'Rosemary M. Collyer': 1,
#   'Collyer': 2,
#   'Trump': 255,
#   'John A. Boehner': 2,
#   'Gola White': 1,
#   'James Fernandez': 2,
#   'Fernandez': 23,
#   'Maria Fernandez': 1,
#   'Sgt': 2,
#   'Michael J. LoPuzzo': 1,
#   'Sergeant LoPuzzo': 4,
#   'Michael R. Bloomberg': 1,
#   'Raymond W. Kelly': 1,
#   'Argenis Rosado': 1,
#   'Hector Espada': 1,
#   'Alexander Avenue': 1,
#   'Russell Lewis': 1,
#   'James P. O’Neill': 2,
#   'Brian Hennessy': 1,
#   'O’Neill': 2,
#   'Bill de Blasio': 4,
#   'Hennessy': 1,
#   'Michael Palladino': 1,
#   'Robert K. Boyce': 1,
#   'Chief Boyce': 1,
#   'Howard Landesberg': 1,
#   'Joseph L. Giacalone': 1,
#   'Darcel D. Clark': 1,
#   'Jeff Meenagh': 1,
#   'Ruben Diaz Jr.': 1,
#   'Jerry O’Sullivan': 1,
#   'Walt Disney’s': 1,
#   'Tyrus Wong': 3,
#   'Wong': 31,
#   'Picasso': 1,
#   'Paul Klee': 1,
#   'John Canemaker': 1,
#   'Wong Gen Yeo': 1,
#   'Romanized Wong Gaing Yoo': 1,
#   'Gen Yeo': 7,
#   'Chester A. Arthur': 1,
#   'Look Tai Yow': 2,
#   'Lisa See': 1,
#   'Pamela Tom': 1,
#   'Tyrus': 1,
#   'Benji Okubo': 1,
#   'Canemaker': 4,
#   'Felix Salten': 1,
#   'landscapes misty': 1,
#   'Ruth Kim': 1,
#   'Okubo': 1,
#   'See': 2,
#   'Ruth Wong’s': 1,
#   'Fred MacMurray': 1,
#   'Julie Andrews': 1,
#   'Tom': 1,
#   'Kay Fong': 1,
#   'Kim Wong': 1,
#   'Muhammad Ali': 1,
#   'Arnold Palmer': 1,
#   'Carrie Fisher': 1,
#   'Debbie Reynolds': 1,
#   'David Bowie': 1,
#   'persona': 1,
#   'Prince Rogers Nelson': 1,
#   'Leonard Cohen': 1,
#   'merry  ': 1,
#   'George Michael': 6,
#   'Paul Kantner': 1,
#   'Greg Lake': 1,
#   'Palmer Glenn': 1,
#   'Maurice White': 1,
#   'Leon Russell': 1,
#   'Merle Haggard': 1,
#   'Ralph Stanley': 1,
#   'Elvis': 1,
#   'Scotty Moore': 1,
#   'George Martin': 1,
#   'Ali': 3,
#   'Arnie': 1,
#   'Hockey': 1,
#   'Ralph Branca': 1,
#   'Bobby Thomson': 1,
#   'Pat Summitt': 1,
#   'Clyde Lovelette': 1,
#   'N. B. A.': 1,
#   'Nate Thurmond': 1,
#   'Kareem': 1,
#   'Monte Irvin': 1,
#   'Antonin Scalia': 1,
#   'Nancy Reagan': 1,
#   'John Glenn’s': 1,
#   'Tom Hayden': 1,
#   'Daniel Berrigan': 1,
#   'Phyllis Schlafly’s': 1,
#   'Janet Reno': 1,
#   'Clinton': 30,
#   'Elián González': 1,
#   'Fidel Castro’s': 1,
#   'Shimon Peres': 2,
#   'Elie Wiesel': 1,
#   'Harper Lee': 1,
#   'Umberto Eco': 1,
#   'Pat Conroy': 1,
#   'Jim Harrison': 1,
#   'Anita Brookner': 1,
#   'Alvin Toffler': 1,
#   'Gloria Naylor': 1,
#   'William Trevor': 1,
#   'Peter Shaffer': 1,
#   'Dario Fo': 1,
#   'Edward Albee': 1,
#   'Fisher': 1,
#   'Reynolds': 1,
#   'Alan Rickman': 1,
#   'Severus Snape': 1,
#   'Zsa Zsa Gabor’s': 1,
#   'Gene Wilder': 1,
#   'Garry Shandling': 1,
#   'Abe Vigoda': 1,
#   'Barney Miller': 1,
#   'Jacques Rivette': 1,
#   'Abbas Kiarostami': 1,
#   'Andrzej Wajda': 1,
#   'Ingmar Bergman': 1,
#   'Akira Kurosawa': 1,
#   'Noel Neill': 1,
#   'Alan Young': 1,
#   'Robert Vaughn': 1,
#   'William Schallert': 1,
#   'Patty Duke': 1,
#   'Dan Haggerty': 1,
#   'Florence Henderson': 1,
#   'Alan Thicke': 1,
#   'Garry Marshall': 1,
#   'Brian Bedford': 1,
#   'Tammy Grimes': 1,
#   'Anne Jackson': 1,
#   'Zaha Hadid': 1,
#   'Bill Cunningham': 1,
#   'Ruth Gruber': 1,
#   'Marc Riboud': 1,
#   'Louis Stettner': 1,
#   'Morley Safer': 1,
#   'Gwen Ifill': 1,
#   'John McLaughlin': 1,
#   'Pierre Boulez': 1,
#   'Phyllis Curtin': 1,
#   'Mose Allison': 1,
#   'Bobby Hutcherson': 1,
#   'Gato Barbieri': 1,
#   'Phife Dawg': 1,
#   'Malik Taylor': 1,
#   'Juan Gabriel': 1,
#   'Andrew S. Grove': 1,
#   'Grant Tinker': 1,
#   'Kim': 11,
#   'Donald J. Trump': 37,
#   'Park': 2,
#   'Cheong': 1,
#   'the U. S. mainland': 1,
#   'Elizabeth II': 1,
#   'Prince Philip': 1,
#   'Tsai': 12,
#   'São Tomé': 1,
#   'Bonnie S. Glaser': 1,
#   'Glaser': 1,
#   'Richard C. Bush': 1,
#   'Danny Cahill': 1,
#   'Cahill': 10,
#   'Jay Leno': 1,
#   'Regis Philbin': 1,
#   'Joy Behar': 1,
#   'Kevin Hall': 1,
#   'Hall': 6,
#   'Kidney Diseases': 1,
#   'Michael Schwartz': 1,
#   'Schwartz': 1,
#   'Robert Huizenga': 1,
#   'David Ludwig': 1,
#   'Margaret Jackson': 1,
#   'leptin levels fall': 1,
#   'Erinn Egbert': 1,
#   'Egbert': 1,
#   'the N. I. H.': 2,
#   'Sean Algaier': 1,
#   'N. C.': 2,
#   'Leptin': 1,
#   'Joseph Proietto': 1,
#   'Proietto': 2,
#   'Lee Kaplan': 1,
#   'Michael Rosenbaum': 1,
#   'Rosenbaum': 2,
#   'Ludwig': 1,
#   'Hillary Kerr': 2,
#   'Andy Warhol': 1,
#   'Jonathan Leahy': 1,
#   'Kerr': 27,
#   'Leahy': 24,
#   'Lena Dunham': 1,
#   'Mary': 1,
#   'Tom Wolfe': 1,
#   'Katherine Power': 1,
#   'Power': 1,
#   'boozy brunch': 1,
#   'Ben Schneider': 1,
#   'John Newman': 1,
#   'Katie': 1,
#   'Vacationer Remix': 1,
#   'Deleted Scenes': 1,
#   'the Roger Room': 1,
#   'Tom Waits': 1,
#   'Jack Antonoff': 1,
#   'Dunham': 2,
#   'Al Wertheimer': 1,
#   'Frank Sinatra': 2,
#   'Ronald Reagan': 3,
#   'Kirk Douglas': 1,
#   'Zsa Zsa Gabor': 1,
#   'Reem Acra': 1,
#   'Jen Atkin': 1,
#   'Joey Maalouf': 1,
#   'App': 1,
#   'Eva Chen': 1,
#   'Leigh Belz Ray': 1,
#   'Hillary': 2,
#   'Ray': 1,
#   'Flora': 1,
#   'Richard': 1,
#   'Marie Leahy': 1,
#   'Carole Kerr': 1,
#   'Marshall Goldsmith': 1,
#   'James Kavanaugh': 1,
#   'Mary Oliver': 1,
#   'Muñiz': 9,
#   'José': 2,
#   'Zoraida Muñiz': 1,
#   'Dickens': 1,
#   'José Jr.': 4,
#   'Maria': 2,
#   'José Sr': 1,
#   'José Sr.': 1,
#   'Zoraida': 1,
#   'Hillary Clinton': 5,
#   'Obama’s': 8,
#   'John Kasich': 1,
#   'Charles E. Grassley': 2,
#   'Grassley': 1,
#   'Tom Kiernan': 1,
#   'Kiernan': 1,
#   'David G. Victor': 1,
#   'Victor': 3,
#   'Petra Nova': 3,
#   'Nippon Oil and Gas Exploration': 1,
#   'David Knox': 1,
#   'Knox': 1,
#   'C. C. S.': 2,
#   'Julio Friedmann': 1,
#   'David Mohler': 1,
#   'Mark Brownstein': 1,
#   'Heidi Heitkamp': 1,
#   'Heitkamp': 2,
#   'Sheldon Whitehouse': 1,
#   'Jeff Erikson': 1,
#   'Rodney Allam': 1,
#   'Bill Brown': 1,
#   'Fatima Maria Ahmad': 1,
#   'Daniel McCarthy': 1,
#   'John Coequyt': 1,
#   'Friedmann': 1,
#   'Sylvester Stallone': 1,
#   'Fabio': 1,
#   'George W. Bush': 8,
#   'Mickey Mouse': 1,
#   'Jeff Greene': 1,
#   'Howie Carr': 1,
#   'Carr': 3,
#   'Eric': 1,
#   'Donald Jr.': 1,
#   'Joe Scarborough': 1,
#   'Mika Brzezinski': 1,
#   'Douglas Brinkley': 1,
#   'Chris Ruddy': 1,
#   'Ruddy': 1,
#   'Laura Ingraham': 1,
#   'Donald Trump': 1,
#   'Rudolph W. Giuliani': 1,
#   'Mitt Romney': 2,
#   'Rex W. Tillerson': 2,
#   'Exxon': 1,
#   'Brian Burns': 1,
#   'Joseph P. Kennedy': 1,
#   'Isaac Perlmutter': 1,
#   'Robert K. Kraft': 1,
#   'Carlos Slim': 1,
#   'Harry Hurt': 1,
#   'David H. Koch': 1,
#   'Hurt': 2,
#   'Robin Bernstein': 1,
#   'Donald': 4,
#   'Brinkley': 1,
#   'Endorphin': 1,
#   'Mpix': 1,
#   'washi tape': 1,
#   'Risograph': 1,
#   'David Pogue’s': 1,
#   'Wirecutter': 2,
#   'Betsy Morris': 1,
#   'Nos': 1,
#   'Harihareswara': 3,
#   'Andrew M. Cuomo': 2,
#   'Cuomo': 15,
#   'Thomas F. Prendergast': 2,
#   'Jill Tallmer': 1,
#   'Margot Tallmer': 1,
#   'Tallmer': 1,
#   'George Braith': 1,
#   'Braith': 3,
#   'Daniel Boulud': 1,
#   'alto': 1,
#   'Ian Ma': 1,
#   'Emanuel A. M. E. Church': 1,
#   'S. C.': 1,
#   'Roof': 41,
#   'Richard M. Gergel': 1,
#   'David I. Bruck': 1,
#   'Gergel': 3,
#   'Bruck': 8,
#   'the F. B. I.': 5,
#   'Robert Dunham': 1,
#   'Michael T. Slager': 1,
#   'Joseph A. Darby': 1,
#   'Darby': 1,
#   'John H. Blume': 1,
#   'Peter D. Greenspun': 1,
#   'John A. Muhammad': 1,
#   'Muhammad': 1,
#   'Greenspun': 2,
#   'Narendra Modi': 1,
#   'Modi': 19,
#   'Hem Raj Chechi': 1,
#   'Chechi': 2,
#   'Eswar S. Prasad': 1,
#   'Prasad': 1,
#   'Mohandas K. Gandhi': 1,
#   'Gandhi': 2,
#   'Mahatma': 1,
#   'Geng Xiao': 1,
#   'Harsh Pant': 1,
#   'Xiao': 1,
#   'Pant': 4,
#   'Nagender Tiwari': 1,
#   'Raj Kumar Bindal': 1,
#   'Surjit Bhalla': 1,
#   'Bhalla': 1,
#   'François Hollande': 2,
#   'Hollande': 4,
#   'Asaad Hashim': 1,
#   'Hashim': 1,
#   'Sadr': 1,
#   'Ali Abbas': 1,
#   'Abadi': 1,
#   'Fuad Masum': 1,
#   'creeks': 1,
#   'Anthony Boxshall': 1,
#   'Boxshall': 2,
#   'Sam Riley': 1,
#   'Aaron Rodgers': 1,
#   'Redskins': 5,
#   'the N. F. C. North': 1,
#   'Seattle Seahawks Time': 1,
#   'Seahawks': 2,
#   'Earl Thomas': 1,
#   'Rams': 1,
#   'Tom Savage': 1,
#   'Brock Osweiler': 1,
#   'Derek Carr': 2,
#   'Matt McGloin': 2,
#   'McGloin': 1,
#   'Connor Cook': 1,
#   'Ryan Tannehill': 1,
#   'Matt Moore': 1,
#   'Jay Ajayi': 1,
#   'the N. F. C.': 1,
#   'Carey': 13,
#   'Bulochnikov': 1,
#   'Dick Clark Productions': 1,
#   'Robert Goldstein': 1,
#   'Goldstein': 1,
#   'Nicole Perna': 1,
#   'Yves Ubelmann': 1,
#   'Ubelmann': 5,
#   'Houmam Saad': 1,
#   'Martinez': 1,
#   'Bashar  ': 1,
#   'Nineveh': 1,
#   'Khorsabad': 1,
#   'Abdulkarim': 1,
#   'Pascal Butterlin': 1,
#   'Butterlin': 1,
#   'Mari': 2,
#   'Cheikhmous Ali': 1,
#   'Lens': 1,
#   'George Michael’s': 3,
#   'Steven Meisel': 1,
#   'Madonna': 3,
#   'Chris Isaak': 1,
#   'Janet Jackson': 1,
#   'David Fincher': 4,
#   'Michael': 2,
#   'Naomi Campbell': 2,
#   'Linda Evangelista': 1,
#   'Christy Turlington': 1,
#   'Cindy Crawford': 1,
#   'Tatjana Patitz': 2,
#   'Camilla Nickerson': 2,
#   'Guido Palau': 1,
#   'Carol Brown': 1,
#   'John Pearson': 2,
#   'Peter Lindbergh': 1,
#   'George': 5,
#   'Christy': 4,
#   'Thierry Mugler': 1,
#   'Kate': 2,
#   'Linda': 9,
#   'Naomi': 2,
#   'L. A. Herb Ritts': 1,
#   'Audrey Hepburn': 1,
#   'Grace Kelly': 1,
#   'Ava Gardner': 1,
#   'Candis Cayne': 1,
#   'N. Y. C.': 1,
#   'Sherry Vine': 1,
#   'O. K.': 2,
#   'Alan Hunter': 1,
#   'V. J. s.': 1,
#   'Zac Posen': 1,
#   'Mitch McConnell': 3,
#   'Obstacles': 1,
#   'Newt Gingrich': 1,
#   'Bob Dole': 1,
#   'Trent Lott': 1,
#   'Obamacare': 2,
#   'Lott': 1,
#   'Chuck Schumer': 7,
#   'Patty Murray': 1,
#   'Paul D. Ryan': 6,
#   'Jeff Sessions': 3,
#   'Dianne Feinstein': 2,
#   'Sessions': 2,
#   'Tom Mentzer': 1,
#   'McConnell': 2,
#   'Merrick B. Garland': 2,
#   'Tom Cole': 1,
#   'Garland': 1,
#   'Newt': 1,
#   'Bill Clinton': 4,
#   'Cory Gardner': 2,
#   'Cole': 1,
#   'Choi': 1,
#   'Narendra Modi’s': 1,
#   'U. S.': 1,
#   'Benjamin Netanyahu': 4,
#   'Richard Nixon': 1,
#   'Nixon': 1,
#   'Mao Zedong': 1,
#   'J. R. R. Tolkien': 1,
#   'Xi Jinping': 4,
#   'Sammy Hagar': 1,
#   'Richard M. Nixon': 1,
#   'm. p. h.': 2,
#   'Chris Stanford': 1,
#   'James N. Mattis': 2,
#   'Ralph Dengler': 1,
#   'Dengler': 1,
#   'Mattis': 5,
#   'T. G. Taylor': 1,
#   'Taylor': 2,
#   'an R. O. T. C.': 1,
#   'David H. Petraeus': 2,
#   'C. I. A.': 5,
#   'Escape': 1,
#   'P. O. W.s': 1,
#   'Hicks': 1,
#   'Bush': 5,
#   'Donald J. Guter': 1,
#   'Nagem Sadoon Hatab': 1,
#   'Jessica Lynch': 1,
#   'Hatab': 7,
#   'William B. Gallo': 1,
#   'Numan Kurtulmus': 1,
#   'Kurtulmus': 2,
#   'Hurriyet': 1,
#   'Aiymkan Kulukeyeva': 1,
#   'Bashar': 2,
#   'Andrey G. Karlov': 1,
#   'Aleppo': 3,
#   'Obama meant': 1,
#   'George W. Bush’s': 1,
#   'Mike Mullen': 1,
#   'Bruce Riedel': 1,
#   'Vali R. Nasr': 1,
#   'Nasr': 1,
#   'Karl W. Eikenberry': 1,
#   'Eikenberry': 2,
#   'Benjamin J. Rhodes': 1,
#   'Ryan Crocker': 1,
#   'Osama bin Laden': 2,
#   'Hamid Karzai': 1,
#   'Karzai': 3,
#   'Crocker': 1,
#   'Ashraf Ghani': 1,
#   'Rhodes': 2,
#   'Oruzgan': 1,
#   'Daniel F. Feldman': 1,
#   'Ghani': 1,
#   'Joseph R. Biden Jr.': 3,
#   'Martin E. Dempsey': 1,
#   'Mullen': 1,
#   'Dempsey': 1,
#   'N. Y.': 4,
#   'Tova Weinstock': 1,
#   'Laura Cattano': 1,
#   'Marie Kondo': 1,
#   'Sharon Lowenheim': 1,
#   'Lowenheim': 6,
#   'Faith Roberson': 1,
#   'Roberson': 3,
#   'Netanyahu': 25,
#   'Avichai Mandelblit': 1,
#   'Ronald S. Lauder': 1,
#   'Lauder': 3,
#   'Helena Beilin': 1,
#   'Daniel B. Shapiro': 1,
#   'Nahum Barnea': 1,
#   'Barnea': 1,
#   'Isaac Herzog': 1,
#   'Herzog': 1,
#   'Yesh Atid': 1,
#   'Ehud Olmert': 1,
#   'Olmert': 2,
#   'Caesarea': 1,
#   'David Shimron': 1,
#   'Arnaud Mimran': 1,
#   'Myriam El Khomri': 1,
#   'Lyon': 1,
#   'Paul Stacey': 1,
#   'Ken Thrower': 1,
#   'Gronych': 2,
#   'Stacey': 2,
#   'Janine Massey': 1,
#   'Luís Carlos Valois': 1,
#   'P. C. C.': 2,
#   'Elon Musk': 1,
#   'McGregor': 1,
#   'Mini Cooper': 1,
#   'S. A. R.': 2,
#   'Amir Gavarin': 1,
#   'Yoni Stone': 1,
#   'Judaic': 1,
#   'N. J.': 4,
#   'Jared Kushner': 2,
#   'Kushner': 5,
#   'R. T. M. A.': 1,
#   'Elizabeth': 1,
#   'David Yeshivah': 1,
#   'Stone': 2,
#   'David Kolb': 1,
#   'Seth Gordon': 1,
#   'Gordon': 1,
#   'Gavarin': 1,
#   'Mayer Schiller': 1,
#   'Rabbi Schiller': 4,
#   'Nick Fotiu': 1,
#   'Kolb': 1,
#   'Gordie': 2,
#   'Howie Falkenstein': 1,
#   'Falkenstein': 3,
#   'Mites': 1,
#   'the S. A. R. Sting’s': 1,
#   'Jonathan Lethem': 1,
#   'Walt Whitman': 1,
#   'James Baldwin': 1,
#   'Marilynne Robinson': 1,
#   'Lethem': 17,
#   'Melissa Barton': 1,
#   'Beinecke': 1,
#   'Barton': 1,
#   'Glenn Horowitz': 1,
#   'Ed Koch': 1,
#   'Philip K. Dick': 1,
#   'Devo': 1,
#   'Oliver Sacks': 1,
#   'Samuel J. Underberg': 1,
#   'Billboard': 1,
#   'Donna Tartt': 1,
#   'Paul Auster': 1,
#   'Suzanne Vega': 1,
#   'Jennifer Egan': 1,
#   'Thomas Berger': 1,
#   'Ursula K. Le Guin': 1,
#   'David Bowman': 1,
#   'David': 1,
#   'Rey Canunayon': 1,
#   'Canunayon': 9,
#   'Greg Hankins': 1,
#   'Hankins': 1,
#   'Kevin McCarthy': 2,
#   'Robert W. Goodlatte': 1,
#   'Steve King': 1,
#   'Mark Sanford': 1,
#   'Ryan': 11,
#   'McCarthy': 5,
#   'Steve Pearce': 1,
#   'Melvin Watt': 1,
#   'Mark Meadows': 1,
#   'Roger Williams': 1,
#   'Markwayne Mullin': 1,
#   'Cathy McMorris Rodgers': 1,
#   'Bobby L. Rush': 1,
#   'Luis V. Gutiérrez': 1,
#   'Goodlatte': 2,
#   'Noah Bookbinder': 1,
#   'Mike Pence': 8,
#   'Robert Lighthizer': 2,
#   'Eric H. Holder Jr.': 2,
#   'B. J. Miller': 1,
#   'Kelly': 39,
#   '• U. S.': 1,
#   'John Colone': 1,
#   'Adiga': 1,
#   'Ruby Tandoh': 1,
#   'Melania Trump  ': 1,
#   'Melanija Knavs': 1,
#   'John Quincy Adams': 1,
#   'Louisa': 3,
#   'John Adams': 1,
#   'Adeel Hassan': 1,
#   'Photographs': 2,
#   'Pete Sessions': 1,
#   'Dick Cheney': 2,
#   'Liz': 1,
#   'Mike Enzi': 1,
#   'James L. Madara': 1,
#   'Nancy Pelosi': 4,
#   'Pelosi': 1,
#   'I. O.': 1,
#   'Richard Trumka': 1,
#   'Trumka': 2,
#   'Lighthizer': 8,
#   'Orrin Hatch': 1,
#   'Hatch': 1,
#   'Bob': 1,
#   'Peter Navarro': 1,
#   'Wilbur Ross': 2,
#   'U. S. T. R.': 1,
#   'Alan Wolff': 1,
#   'Navarro': 1,
#   'Gary D. Cohn': 2,
#   'Terry Branstad': 1,
#   'Scott Lincicome': 1,
#   'Lincicome': 1,
#   'Nafta': 1,
#   'Cruze': 1,
#   'Mustang': 1,
#   'Mark Fields': 1,
#   'Reagan': 4,
#   'John McCain': 4,
#   'Julian Assange': 1,
#   'Assange': 15,
#   'Sean Hannity': 3,
#   'Hillary Clinton’s': 3,
#   'John Podesta': 2,
#   'Hannity': 1,
#   'Donna Brazile': 2,
#   'Podesta': 10,
#   'Bernie Sanders': 2,
#   'Brazile': 2,
#   'Pence': 5,
#   'Manigault': 3,
#   'Bill Stepien': 1,
#   'Chris Christie': 2,
#   'Keith Schiller': 1,
#   'John DeStefano': 1,
#   'George Gigicos': 1,
#   'Joe Hagin': 1,
#   'Roanld Reagan': 1,
#   'George Bush': 1,
#   'Rick Dearborn': 1,
#   'Katie Walsh': 1,
#   'Priebus': 1,
#   'Kellyanne Conway': 1,
#   'Walsh': 1,
#   'Schumer': 8,
#   'Jay Clayton': 1,
#   'Vladimir V. Putin': 5,
#   'Holder': 5,
#   'Kevin de León': 1,
#   'de León': 4,
#   'Anthony Rendon': 1,
#   'Jerry Brown': 1,
#   'Xavier Becerra': 1,
#   'Kamala D. Harris': 1,
#   'Becerra': 1,
#   'Brown': 6,
#   'Elor Azaria': 1,
#   'David Enoch': 1,
#   'Sergeant Azaria': 11,
#   'Avigdor Lieberman': 1,
#   'Lieberman': 2,
#   'Naftali Bennett': 1,
#   'Shelly Yacimovich': 1,
#   'Maya Heller': 1,
#   'Describing Sergeant Azaria’s': 1,
#   'Abed     ': 1,
#   'Ilan Katz': 1,
#   'Gadi Eisenkot': 1,
#   'Sharif': 5,
#   'Tom Naaman': 1,
#   'Ahmad Tibi': 1,
#   'Tibi': 1,
#   'Johnson  Johnson': 1,
#   'Jack Groppel': 1,
#   'Groppel': 1,
#   'S. P.': 1,
#   'Ellie Mae': 1,
#   'Douglas Dynamics': 1,
#   'Megyn Kelly': 2,
#   'Murdoch': 1,
#   'Bill O’Reilly': 2,
#   'Roger Ailes': 2,
#   'Andrew Lack': 2,
#   'Ailes': 3,
#   'Rupert Murdoch': 1,
#   'Lack': 5,
#   'Douglas Brunt': 1,
#   'Brian Williams': 2,
#   'Rachel Maddow': 1,
#   'Lawrence O’Donnell': 1,
#   'Megyn': 1,
#   'Charlie Rose': 3,
#   'Oprah Winfrey': 1,
#   'Barbara Walters': 1,
#   'Robert Shapiro': 1,
#   'Laverne Cox  ': 1,
#   'Jane Pauley': 1,
#   'Meredith Vieira': 1,
#   'Katie Couric': 1,
#   'Anderson Cooper': 1,
#   'Pauley': 1,
#   'p. m. Eastern': 1,
#   'Greta Van Susteren': 1,
#   'Sandra Smith': 1,
#   'Trish Regan': 1,
#   'Martha MacCallum': 1,
#   'Tucker Carlson': 1,
#   'Fox': 1,
#   'Hogwarts': 1,
#   'Wang Kai': 1,
#   'Cristiano Ronaldo': 1,
#   'Ronaldo': 1,
#   'Messi': 1,
#   'Antonio Conte': 1,
#   'Xi': 6,
#   'Simon Chadwick': 1,
#   'Cameron Wilson': 1,
#   'Xu Yun': 1,
#   'Wilson': 5,
#   'David Beckham': 1,
#   'FIFA TMS': 1,
#   'Dai Wei': 1,
#   'r. Xi’s old': 1,
#   'Dai': 1,
#   'Liu Jiangnan': 1,
#   'Sergio Zarco Diaz': 1,
#   'Zhang Lu': 1,
#   'Zhang': 3,
#   'Lin Yanling': 1,
#   'Bill Gates': 1,
#   'Jeff Bezos': 1,
#   'Bezos': 1,
#   'the U. S.': 2,
#   'Julius Genachowski': 1,
#   'Genachowski': 2,
#   'Tom Wheeler': 1,
#   'Panzhihua': 1,
#   'Mao': 1,
#   'Chen Zhongshu': 1,
#   'Chen': 2,
#   'Li Jianqin': 1,
#   'Zhang Yan': 1,
#   'Li': 1,
#   'killings': 1,
#   'Stephen P. Davis': 1,
#   'David M. Kennedy': 1,
#   'Kennedy': 2,
#   'Sarah Palin’s': 1,
#   'Steve Bannon': 1,
#   'Howard Dean': 1,
#   'Brexit': 1,
#   'Joseph McCarthy': 1,
#   'Richard Hofstadter': 1,
#   'Dwight Eisenhower': 1,
#   'Adlai Stevenson': 1,
#   'C. Wright Mills': 1,
#   'William F. Buckley Jr.': 1,
#   'Barry Goldwater': 1,
#   'Lyndon Johnson': 1,
#   'Rush Limbaugh': 1,
#   'Bill Clinton’s': 1,
#   'Christopher Lasch': 1,
#   'Chris Hayes': 1,
#   'Litman': 2,
#   'Michelis': 3,
#   'Fallsgraff': 8,
#   'Purcell': 3,
#   'Bui': 2,
#   'Meagher': 3,
#   'Grossman': 2,
#   'Fogelman': 3,
#   'Phillips': 4,
#   'Whelden': 1,
#   'Delaney': 1,
#   'Roth': 3,
#   'Marini': 5,
#   'Powell': 6,
#   'Albertson': 3,
#   'Turke': 3,
#   'Helmling': 3,
#   'Stucky': 4,
#   'Mathiowetz': 3,
#   'N. H.': 1,
#   'Alicia Rivera': 1,
#   'Rivera': 16,
#   'Nelson': 7,
#   'Alyssa': 2,
#   'Rafael': 1,
#   'Joaquin': 1,
#   'Chris Collins': 1,
#   'Collins': 1,
#   'Donald Trump’s': 1,
#   'Ted Cruz': 1,
#   'John Cornyn': 1,
#   'Cornyn': 1,
#   'Debbie Stabenow': 1,
#   'Hank Johnson': 1,
#   'Johnson': 1,
#   'Jeff Merkley': 1,
#   'A.': 1,
#   'Robert C. Byrd': 1,
#   'Walter B. Jones': 1,
#   'Tom DeLay': 1,
#   'John Feehery': 1,
#   'Jones': 1,
#   'Ivanka Trump': 1,
#   'Dan K. Rapoport': 1,
#   'William F. X. Moody': 1,
#   'Tony Podesta': 1,
#   'Tracy Place': 1,
#   'John Damgard': 1,
#   'Damgard': 1,
#   'Renee Zlotnick Kraft': 1,
#   'Rapoport': 2,
#   'Vladimir Ashurkov': 1,
#   'Aleksei A. Navalny': 1,
#   'Navalny': 1,
#   'Ashurkov': 1,
#   'Walter J. Clayton': 1,
#   'Clayton': 20,
#   'Jay': 1,
#   'Mary Jo White': 1,
#   'Rupert Murdoch’s': 1,
#   'Kenneth D. Lewis': 1,
#   'Laura S. Unger': 1,
#   'Sullivan  Cromwell': 1,
#   'Warren E. Buffett’s': 1,
#   'Berkshire Hathaway': 1,
#   'The S. E. C.': 1,
#   'Steven T. Mnuchin': 1,
#   'Stephen K. Bannon': 1,
#   'Sullivan': 1,
#   'H. Rodgin Cohen': 1,
#   'Cohen': 2,
#   'Sherrod Brown': 1,
#   'the S. E. C.': 2,
#   'Richard Truesdell': 1,
#   'Harvey Pitt': 1,
#   'Pitt': 1,
#   'Jeb Bush’s': 1,
#   'Brad Whitman': 1,
#   'S. C.  ': 1,
#   'Dylann S. Roof': 1,
#   'Nathan S. Williams': 1,
#   'Williams': 2,
#   'F. B. I.': 13,
#   'Clementa C. Pinckney': 1,
#   'Jennifer Benjamin Pinckney': 1,
#   'Pinckney': 10,
#   'Julius N. Richardson': 1,
#   'Kylon Middleton': 1,
#   'Cynthia Hurd': 1,
#   'Susie Jackson': 1,
#   '87 Ethel Lee Lance': 1,
#   'Daniel Lee Simmons Sr': 1,
#   'Sharonda': 1,
#   'Myra Thompson': 1,
#   'Thompson': 3,
#   'Anthony B. Thompson': 1,
#   'Reina': 1,
#   'Recep Tayyip Erdogan': 1,
#   'Fethullah Gulen': 1,
#   'Erdogan': 8,
#   'Binali Yildirim': 1,
#   'Yildirim': 1,
#   'Aydin Engin': 1,
#   'Bosporus': 1,
#   'Soli Ozel': 1,
#   'Tugrul Eryilmaz': 1,
#   'Luis Buñuel': 1,
#   'Soner Cagaptay': 1,
#   'Gulen': 1,
#   'Assad': 1,
#   'Jens Laerke': 1,
#   'Mevlut Cavusoglu': 1,
#   'Laerke': 1,
#   'Sajjad Malik': 1,
#   'Malik': 2,
#   'Port Hardy': 2,
#   'Emily Carr': 1,
#   'Celine Dion': 1,
#   'B. C.': 1,
#   'Claude': 1,
#   'Madeleine Thien': 1,
#   'Charles Kingsmill': 1,
#   'Diana': 1,
#   'David Bearman': 1,
#   'Jennifer Trant': 1,
#   'Cory Doctorow': 1,
#   'Pierre Berton': 1,
#   'Kim Fu': 1,
#   'Hans Johann': 1,
#   'Barbara': 1,
#   'Sarah Nicole': 1,
#   'Sarah': 1,
#   'Opa': 1,
#   'Sarah Nicole Prickett': 1,
#   'Chemin St.': 1,
#   'Hunter Mills': 1,
#   'Élise Turcotte': 1,
#   'Guyana': 1,
#   'Allison M. Charette': 1,
#   'village de mon': 2,
#   'j’aimais la': 1,
#   'de ma tête': 1,
#   'Je voyais aussi': 1,
#   'aussi à mon': 1,
#   'mon doigt sur un': 1,
#   'J’avais aussi': 1,
#   'Je': 1,
#   'laisse': 1,
#   'J’imaginais aussi': 1,
#   'la famine': 1,
#   'laissé': 1,
#   'aussi': 1,
#   'de la': 1,
#   'Je pensais': 1,
#   'mon': 1,
#   'historienne de Stanbridge Station': 1,
#   'belle': 1,
#   'du Québec': 1,
#   'de Hunter Mills': 1,
#   'Québec': 1,
#   'qui': 2,
#   'ma terre': 1,
#   'ma maison': 1,
#   'j’y ai': 1,
#   'le débarras': 1,
#   'une maison à l’abandon de vieux': 1,
#   'de vieux': 1,
#   'qui ronronne': 1,
#   'Maureen Towey': 1,
#   'Josh Haner': 1,
#   'Pink': 1,
#   'Jimi Hendrix': 1,
#   'Monte Carlo': 1,
#   'Manu Katché': 1,
#   'Richard Bona': 1,
#   'Ibrahim Maalouf': 1,
#   'Basil’s Bar': 1,
#   'Joe Louis Walker': 1,
#   'Mick Jagger': 1,
#   'Michael Kors': 1,
#   'Anna Netrebko': 1,
#   'Gustavo Dudamel': 1,
#   'Roger Waters': 1,
#   'Opéra de Montréal': 1,
#   'Belmond Hiram': 1,
#   ...},
#  'ORG': {'Trump': 23,
#   'House': 84,
#   'Capitol Hill': 10,
#   'the United States Court of Appeals': 1,
#   'Congress': 68,
#   'the Affordable Care Act': 9,
#   'The Justice Department': 1,
#   'the Treasury Department': 1,
#   'The White House': 2,
#   'the White House': 31,
#   'Obama White House': 1,
#   'New York Times': 3,
#   'Police Department': 2,
#   'the Police Department’s': 1,
#   'Times': 27,
#   'the Betances Houses': 5,
#   'Hennessy': 1,
#   'Police Service Area 7': 1,
#   'the New York of the 1980s': 1,
#   'strip club brawls': 1,
#   'the Police Department': 4,
#   'the Detectives’ Endowment Association': 1,
#   'the City Council': 1,
#   'Brooklyn': 1,
#   'Disney': 15,
#   'the Art Institute of Chicago': 1,
#   'Matisse': 1,
#   'Warner Brothers': 3,
#   'New York University': 1,
#   'the Disney Family Museum': 1,
#   'the Otis Art Institute': 1,
#   'the Otis College of Art and Design': 1,
#   'the Works Progress Administration': 1,
#   'the Oriental Artists’ Group of Los Angeles': 1,
#   'Oriental Artists’ Group': 1,
#   'Hallmark': 1,
#   'a Disney Legend': 1,
#   'the Walt Disney Company': 1,
#   'the Chinese American Museum': 1,
#   'The Disney Family Museum’s': 1,
#   'the Museum of Chinese': 1,
#   'Jefferson Airplane Keith Emerson': 1,
#   'Gordie Howe': 1,
#   'the National Hockey League': 1,
#   'National League': 1,
#   'the National Basketball Association': 1,
#   'Negro': 1,
#   'the Hall of Fame': 1,
#   'Major League Baseball’s': 1,
#   'Supreme Court': 4,
#   'White House': 12,
#   'Senate': 69,
#   'Boutros': 1,
#   'the United Nations': 7,
#   'Auschwitz': 1,
#   'Snape': 1,
#   'Intel': 1,
#   'NBC': 20,
#   'Henry J. Heimlich': 1,
#   'Marion Pritchard': 1,
#   'the Constitutional Court': 1,
#   'the Sejong Institute': 1,
#   'Unha': 1,
#   'Musudan': 1,
#   'the United Nations Security Council': 1,
#   'Sandringham, Buckingham Palace': 1,
#   'Sandringham': 1,
#   'King Bhumibol Adulyadej of': 1,
#   'Democratic Progressive Party': 1,
#   'the Center for East Asia Policy Studies': 1,
#   'the Brookings Institution': 1,
#   'The Chinese Ministry of Foreign Affairs': 1,
#   'the National Institute of Diabetes and Digestive': 1,
#   'the National Institutes of Health': 1,
#   'the University of Washington': 1,
#   'Obesity': 1,
#   'the New Balance Foundation Obesity Prevention Center': 1,
#   'Boston Children’s Hospital': 1,
#   'Pfizer': 1,
#   'Australia’s': 1,
#   'National Health and Medical Research Council': 1,
#   'the University of Melbourne': 1,
#   'the “Biggest Loser': 1,
#   'Shower': 1,
#   'Harvard': 4,
#   'Columbia University': 1,
#   'Tigger': 1,
#   'HBO': 3,
#   'the College of William': 1,
#   'Aperture Music': 1,
#   'the University of Southern California': 1,
#   'Elle': 2,
#   'Target': 1,
#   'Fleetwood Mac': 1,
#   'the Colony Palms Hotel': 1,
#   'Instagram': 2,
#   'InStyle': 1,
#   'Colony Palms Hotel': 1,
#   'the Supreme Court’s': 1,
#   'Zoraida': 1,
#   'Muñizes': 1,
#   'Muñiz': 1,
#   'Catholic Charities Archdiocese': 1,
#   'The New York Times’s': 1,
#   'Neediest Cases Fund': 1,
#   'the Neediest Cases Fund': 1,
#   'the New York Film Academy’s': 1,
#   'Treasury': 3,
#   'Statoil': 1,
#   'the Republican Party': 2,
#   'the American Wind Energy Association': 1,
#   'the University of California at San Diego': 1,
#   'THOMPSONS': 1,
#   'NRG': 5,
#   'Nova': 1,
#   'Future Gen': 1,
#   'the Intergovernmental Panel on Climate Change': 1,
#   'the International Energy Agency': 1,
#   'the Lawrence Livermore Laboratories': 1,
#   'Energy Department': 2,
#   'the Environmental Defense Fund': 1,
#   'Net Power': 2,
#   'the Center for Climate and Energy Solutions': 1,
#   'CBI': 2,
#   'Toshiba': 1,
#   'RUD': 1,
#   'Sierra Club': 1,
#   'Groups': 1,
#   'Marjorie Meriweather Post': 1,
#   'Trump Tower': 2,
#   'MSNBC': 6,
#   'Newsmax Media': 1,
#   'Exxon Mobil': 2,
#   'the Department of Veteran Affairs': 1,
#   'Marvel Entertainment': 1,
#   'the New England Patriots': 1,
#   'Barron': 2,
#   'Secret Service': 1,
#   'Salad': 1,
#   'New Mexico State University': 1,
#   'Walgreens': 1,
#   'Costco': 1,
#   'Parabo Press': 2,
#   'Parabo': 1,
#   'SnapBox': 2,
#   'Tokyo Tower': 1,
#   'the Better Business Bureau': 1,
#   'The New York Times': 13,
#   'Memories Renewed': 2,
#   'Google Photos': 1,
#   'Metropolitan Transportation Authority': 1,
#   'New Yorker': 1,
#   'Federal District Court': 2,
#   'the Death Penalty Information Center': 1,
#   'North Charleston': 1,
#   'the African Methodist Episcopal Church': 1,
#   'the Justice Department': 2,
#   'Cornell Law School': 1,
#   'the Supreme Court': 4,
#   'MUMBAI': 1,
#   'Cornell University': 1,
#   'Satyagraha': 1,
#   'the University of Hong Kong': 2,
#   'Parliament': 6,
#   'the Observer Research Foundation': 1,
#   'the Indian National Congress': 1,
#   'the Observatory Group': 1,
#   'BAGHDAD': 1,
#   'The Islamic State': 2,
#   'ISIS': 4,
#   'The Environment Protection Authority': 1,
#   'Fahrenheit': 1,
#   'the Washington Redskins': 1,
#   'the Detroit Lions': 1,
#   'Giants': 7,
#   'Lions': 9,
#   'Fox Thanks': 1,
#   'ESPN': 1,
#   'CBS': 4,
#   'Tannehill': 1,
#   'Redskins': 1,
#   'the Oakland Raiders': 1,
#   'the Denver Broncos': 1,
#   'the Kansas City Chiefs’': 1,
#   'the San Diego Chargers': 1,
#   'The New England Patriots': 1,
#   'the Atlanta Falcons': 1,
#   'the Tampa Bay Buccaneers': 1,
#   'the Carolina Panthers': 1,
#   'Tampa Bay': 1,
#   'ABC': 8,
#   'Rockin’ Eve With Ryan Seacrest': 2,
#   'Us Weekly': 1,
#   'Maryland Sound International': 1,
#   'The Associated Press': 4,
#   'the Islamic State': 10,
#   'Palmyra': 1,
#   'Nimrud': 2,
#   'Time': 7,
#   'the Association for the Protection of Syrian Archaeology': 1,
#   'the “Eternal Sites': 1,
#   'YouTube': 3,
#   'British Vogue': 2,
#   'Cindy': 1,
#   'MTV': 3,
#   'Guido Palau': 1,
#   'the Affordable Care Act’s': 1,
#   'Medicare': 4,
#   'the Senate Finance Committee': 2,
#   'Reince Priebus': 2,
#   'Congressional Review Act': 1,
#   'the Senate Judiciary Committee': 1,
#   'the United States Supreme Court': 1,
#   'Republican Party': 2,
#   'the Tea Party': 1,
#   'Constitutional Court': 1,
#   'Choi': 1,
#   'Samsung': 1,
#   '• House': 1,
#   'India’s Supreme Court': 1,
#   'Bharatiya Janata Party': 1,
#   'Google': 6,
#   'Apple': 25,
#   'The New York Times] • Suicide': 1,
#   'Al Jazeera] •': 1,
#   'Quetta': 1,
#   'Reuters': 1,
#   'The New York Times] • Pan Pan': 1,
#   'The New York Times] •': 1,
#   'Quadrantids': 1,
#   'Rings': 1,
#   'OPEC': 1,
#   'the Emergency Highway Energy Conservation Act': 1,
#   'the Geneva Conventions': 3,
#   'Marine': 2,
#   'Army': 4,
#   'Senate Armed Services Committee': 1,
#   'the Joint Personnel Recovery Agency': 1,
#   'the C. I. A. ’s': 1,
#   'Red Cross': 1,
#   'the South Texas College of Law': 1,
#   'The Department of Defense': 1,
#   'Iraqi Army': 1,
#   'United States': 1,
#   'United States Army': 1,
#   'General Mattis': 1,
#   'Marines': 1,
#   'Marine Corps': 1,
#   'ISTANBUL': 2,
#   'the Foreign Ministry': 1,
#   'the Nashir Media Foundation': 1,
#   'Islamic State': 3,
#   'the National Security Council': 1,
#   'Taliban': 7,
#   'the Joint Chiefs of Staff': 4,
#   'Pentagon': 4,
#   'State Department': 4,
#   'the Johns Hopkins School of Advanced International Studies': 1,
#   'Al Qaeda': 2,
#   'the Pentagon’s Central Command': 1,
#   'the University of Chicago': 1,
#   'General Petraeus': 2,
#   'the American Embassy': 2,
#   'Navy': 4,
#   'Air Force': 2,
#   'National Security Council': 1,
#   'ISIL': 1,
#   'Afghan Army': 1,
#   'the United States Military Academy': 1,
#   'NATO': 4,
#   'MacArthur': 1,
#   'the Organizing Goddess': 1,
#   'Organize With Faith': 1,
#   'The Ministry of Justice': 1,
#   'Lahav 433': 1,
#   'Haaretz': 1,
#   'Likud Party': 1,
#   'a United Nations Security Council': 1,
#   'Yedioth Ahronoth': 1,
#   'the Zionist Union': 1,
#   'Likud': 1,
#   'Netanyahus': 1,
#   'universal health care': 1,
#   'Monoprix': 1,
#   'Lyon': 1,
#   'Miroslav Gronych': 1,
#   'the Calgary Police Service': 1,
#   'the Calgary Police Service’s': 1,
#   'Transport Canada': 1,
#   'Sunwing Airlines': 1,
#   'RIO DE JANEIRO': 1,
#   'Amazon': 7,
#   'Manaus': 6,
#   'Facebook': 4,
#   'First Capital Command': 1,
#   'Amazonas State': 1,
#   'the First Capital Command': 1,
#   'Carandiru': 1,
#   'Umanizzare': 1,
#   'Red Command': 1,
#   'Space Exploration Technologies Corporation': 1,
#   'Cape Canaveral Air Force Station': 1,
#   'the Federal Aviation Administration': 1,
#   'NASA': 3,
#   'the National Transportation Safety Board': 2,
#   'the International Space Station': 1,
#   'Department of Defense': 1,
#   'SpaceX': 1,
#   'CNBC': 2,
#   'Iridium Communications': 1,
#   'Iridium': 2,
#   'Vandenberg Air Force Base': 1,
#   'the Yeshiva University High School for Boys': 2,
#   'Dungeon': 1,
#   'the Salanter Akiba Riverdale High School': 1,
#   'Sabbath': 1,
#   'the Frisch School': 2,
#   'the Ramaz School': 2,
#   'the Israeli Army': 2,
#   'The Ramaz School': 1,
#   'the Rams of Ramaz': 1,
#   'the Rav Teitz Mesivta Academy': 1,
#   'Flatbush': 1,
#   'the Yeshivat Darche Eres': 1,
#   'MSG Networks': 1,
#   'Towns': 1,
#   'the Hebrew Academy of': 1,
#   'Rockaway': 1,
#   'the Hebrew Academy': 1,
#   'the Metropolitan Yeshiva High School Athletic League': 1,
#   'Yeshiva University High School': 1,
#   'Ramones': 1,
#   'Rangers': 2,
#   'Frisch': 1,
#   'The Beinecke Rare Book  Manuscript Library': 1,
#   'Yale University': 1,
#   'Sinclair Lewis': 1,
#   'Yale': 3,
#   'Pomona College': 1,
#   'Bennington College': 1,
#   'Tourette': 2,
#   'MaryGwen': 1,
#   'Canunayons': 2,
#   'St. Adalbert Roman Catholic Church': 1,
#   'the Roman Catholic Diocese': 1,
#   'Community Health Advocates': 1,
#   'the Community Service Society': 1,
#   'The New York Times Neediest Cases Fund': 2,
#   'The Community Service Society': 1,
#   'the Office of Congressional Ethics': 8,
#   'House Ethics Committee': 1,
#   'The House Ethics Committee': 1,
#   'the Ethics Committee': 5,
#   'The Office of Congressional Ethics': 1,
#   'the House Judiciary Committee': 1,
#   'Citizens for Responsibility and Ethics': 1,
#   'General Motors': 6,
#   'Ford': 5,
#   'the California Legislature': 2,
#   'Fox News': 15,
#   'Aravind Adiga’s': 1,
#   'Titanic': 14,
#   'Houses': 1,
#   'Eastern': 1,
#   'Capitol': 1,
#   'the Budget Committee': 2,
#   'the Senate Budget Committee': 1,
#   'The American Medical Association': 1,
#   'the Judiciary Committee': 1,
#   'Chevrolet': 2,
#   'the North American Free Trade Agreement': 1,
#   'Goldman Sachs': 9,
#   'the National Economic Council Rex W. Tillerson': 1,
#   'White  Case': 1,
#   'Chevy': 1,
#   'Cruze': 1,
#   'Ford Focus': 1,
#   'Omarosa Manigault': 1,
#   'the Ecuadorean Embassy': 1,
#   'the Democratic National Committee': 3,
#   'DCLeaks': 2,
#   'the D. N. C. and Podesta': 1,
#   'the Senate Armed Services Committee': 2,
#   'CNN': 7,
#   'the White House Office of Public Liaison': 1,
#   'Oval Office': 1,
#   'the Office of Legislative Affairs': 1,
#   'the Office of Intergovernmental Affairs': 1,
#   'Cabinet Affairs': 1,
#   'the Republican National Committee under Reince Priebus': 1,
#   'the Office of Public Liaison': 1,
#   'Medicaid': 7,
#   'the Securities and Exchange Commission': 3,
#   'Legislature': 4,
#   'Assembly': 2,
#   'Trump White House': 1,
#   'The Democratic Party': 1,
#   'Covington  Burling': 1,
#   'Covington': 1,
#   'the Israel Defense Forces': 1,
#   'the I. D. F.': 1,
#   'the Hebrew University of Jerusalem': 1,
#   'the Labor Party': 1,
#   'Azaria': 1,
#   'Sergeant Azaria’s': 1,
#   'the Israeli Parliament': 1,
#   'the International Journal of Behavioral Nutrition and Physical Activity': 1,
#   'the University of Colorado Anschutz Medical Campus': 1,
#   'the Johnson  Johnson Human Performance Institute': 2,
#   'the Colorado Nutrition Obesity Research Center': 1,
#   'Forbes': 1,
#   'Money': 1,
#   'Barron’s': 1,
#   'Vanguard’s Total Stock': 1,
#   'Kennametal': 1,
#   'Burlington Stores': 1,
#   'NBC News': 7,
#   'Fox News’s': 2,
#   'Greta Van Susteren': 1,
#   'Fox': 14,
#   'Fox’s': 4,
#   'ABC News': 1,
#   'The Wall Street Journal': 4,
#   'NBC Universal': 1,
#   'Oprah': 1,
#   'the National Football League': 1,
#   'NBC News’s': 1,
#   'Fox Business Network Shannon Bream': 1,
#   'Kimberly Guilfoyle': 1,
#   'Evergrande Football School': 1,
#   'Chelsea': 1,
#   'the University of Salford': 1,
#   'People’s Daily': 1,
#   'the Communist Party': 1,
#   'Wild East Football': 1,
#   'FIFA': 1,
#   'the Women’s World Cup': 1,
#   'Chinese Super League': 1,
#   'Premier League': 1,
#   'the Bayi School': 1,
#   'Caoqiao Elementary School': 1,
#   'IBM': 1,
#   'Yahoo': 1,
#   'Microsoft': 3,
#   'Alphabet, Google’s': 1,
#   'Alphabet’s': 1,
#   'Airbnb, Uber and Snap': 1,
#   'the Federal Bureau of Investigation': 2,
#   'iPhone': 6,
#   'iPhones': 1,
#   'The Washington Post': 3,
#   'the Federal Communications Commission': 1,
#   'the Carlyle Group': 1,
#   'Next Big Thing': 1,
#   'Communist Party': 2,
#   'the city party committee': 1,
#   'Sichuan Daily': 1,
#   'the John Jay College': 1,
#   'Criminal Justice': 1,
#   'The New York Police Department': 1,
#   'Detective Bureau': 1,
#   'The   Club for Growth': 1,
#   'New York         ': 1,
#   'American Life': 1,
#   'the Montauk Point Lighthouse': 1,
#   'Organizing for Action': 1,
#   'Champagne': 2,
#   'the New York City Department of City Planning': 1,
#   'the Metropolitan Transportation Authority': 3,
#   'Overboard': 1,
#   'Park Slope': 1,
#   'OkCupid': 1,
#   'Jumbotron': 1,
#   'the NoMad Hotel': 1,
#   'the George Washington Bridge': 1,
#   'Plaza College': 1,
#   'Metropolitan College': 1,
#   'Joaquin': 2,
#   'the Knowledge and Power Preparatory Academy': 1,
#   'Fordham University': 1,
#   'the Family Assistance Program': 1,
#   'Children’s Aid': 1,
#   'The Children’s Aid Society': 1,
#   'the Congressional Research Service': 1,
#   'the Congressional Budget and Impoundment Control': 1,
#   'The Omnibus Budget Reconciliation Act': 1,
#   'Social Security': 2,
#   'the Balanced Budget Act': 1,
#   'the Children’s Health Insurance Program': 1,
#   'the Select Committee on Ethics': 1,
#   'Irina': 1,
#   'Washingtonian': 1,
#   'Washington Fine Properties': 1,
#   'the Podesta Group': 1,
#   'The white house': 1,
#   'the Secret Service': 1,
#   'Rapoport Capital': 1,
#   'Georgetown': 1,
#   'Barclays Capital': 1,
#   'Lehman Brothers': 1,
#   'Bear Stearns': 1,
#   'JPMorgan Chase': 4,
#   'Alibaba Group of China': 1,
#   'Debevoise  Plimpton': 1,
#   'Bank of America': 1,
#   'Goldman’s': 1,
#   'Goldman': 3,
#   'Goldman’s No': 1,
#   'Trump’s': 1,
#   'Capital Management': 1,
#   'Sullivan  Cromwell': 2,
#   'Davis Polk’s': 1,
#   'the S. E. C.': 1,
#   'the University of Pennsylvania': 2,
#   'the University of Cambridge': 1,
#   'the University of Pennsylvania Law School': 1,
#   'Morgan Stanley': 1,
#   'Justice Department': 1,
#   'Malana': 1,
#   'Reformed Episcopal Church': 1,
#   'the Gospel of Mark': 1,
#   'CIA': 1,
#   'Cumhuriyet': 1,
#   'Santa Claus': 1,
#   'Islam': 1,
#   'the Washington Institute for Near East Policy': 1,
#   'Hezbollah': 1,
#   'The Syrian Observatory for Human Rights': 1,
#   'eastern': 1,
#   'United Nations': 5,
#   'Matilda': 1,
#   'Kwakiutl': 3,
#   'First Nations': 2,
#   'the Royal Canadian Navy': 1,
#   'Quakers': 3,
#   'Grindstone': 4,
#   'Moonwatcher’s Point': 1,
#   'the Electronic Frontier Foundation': 2,
#   'Hawker Siddeley HS': 1,
#   'Hawker': 1,
#   'Yukon': 2,
#   'German Mennonites': 1,
#   'Oma and Opa': 1,
#   'Oma and Opa’s': 1,
#   'Mercedes': 3,
#   'BB': 1,
#   'Pigs': 1,
#   'Adult Magazine': 1,
#   'Melville': 1,
#   'the Québécois Mystic': 1,
#   'Cavalier': 2,
#   'beech': 1,
#   'un': 4,
#   'Cette': 1,
#   'une ville homonyme aux   ': 1,
#   'il y avait': 1,
#   'dans un musée': 1,
#   'une salle dédiée': 1,
#   'J’inventais d’ores': 1,
#   'entre moi prenant des': 1,
#   'une': 4,
#   'pensais à la fuite des loyalistes': 1,
#   'Abénaquis des Premières Nations': 1,
#   'qui': 1,
#   'j’étais': 1,
#   'Je': 2,
#   'dans le bureau du tourisme': 1,
#   'grandeur veillaient sur les': 1,
#   'Travel': 1,
#   'Banff': 1,
#   'Mounties': 1,
#   '360 News': 1,
#   'Summerfest': 1,
#   'Henry Maier Festival Park': 1,
#   'The Red Hot Chili Peppers': 1,
#   'The Monterey International Pop Festival': 1,
#   'the Mustique Blues Festival': 1,
#   'the Vienna Philharmonic': 1,
#   'Elbphilharmonie': 1,
#   'Viva Beethoven': 1,
#   'Brightline': 1,
#   'MiamiCentral': 1,
#   'Alps': 1,
#   'Lugano': 1,
#   'Belmond Andean Explorer': 1,
#   'Cusco': 2,
#   'Lake Titicaca': 1,
#   'Arequipa': 1,
#   'Hokkaido': 2,
#   'Celebrity Cruises': 1,
#   'the Celebrity Xploration': 1,
#   'National Geographic Quest': 1,
#   'Star Clippers': 1,
#   'Flying Clipper': 1,
#   'Uniworld Boutique River Cruise Collection': 1,
#   'Crystal River Cruises': 1,
#   'Crystal': 1,
#   'Boeing': 1,
#   'Peninsula Hotels': 1,
#   'Newfoundland': 2,
#   'Wilson': 3,
#   'Manhattan Theater Club': 1,
#   'the Signature Theater': 1,
#   'the Sydney Theater Company': 1,
#   'Platonov': 1,
#   'Irish Rep': 1,
#   'the Irish Repertory Theater': 1,
#   'the Public Theater': 1,
#   'the Druid Theater': 1,
#   'the Brooklyn Academy of Music': 1,
#   'the Association for a Better New York': 1,
#   'the Port Authority of New York': 1,
#   'the Port Authority': 1,
#   'Newark Liberty International Airport': 1,
#   'AirTrain': 2,
#   'JetBlue Airways': 1,
#   'Delta Air Lines': 1,
#   'the Central Terminal Building': 1,
#   'the Van Wyck Expressway': 1,
#   'PAN': 4,
#   'Lagunes': 3,
#   'Nieto': 1,
#   'PRI': 1,
#   'Moreno Valle’s': 3,
#   'Madero': 2,
#   'Cordero': 3,
#   'Hacking Team  ': 1,
#   'Podesta': 7,
#   'Sony': 5,
#   'Hacking Team': 35,
#   'Insider Surveillance': 1,
#   'FinFisher': 1,
#   'Trovicor': 1,
#   'the National Security Agency': 3,
#   'the Remote Control System': 11,
#   'Skype': 4,
#   'the Drug Enforcement Administration': 1,
#   'Puebla, Hacking Team': 1,
#   'Hacking Team’s': 24,
#   'LEAs': 1,
#   'Hacked Team': 1,
#   'pdf': 1,
#   'Passw0rd': 1,
#   'the Hacked Team': 5,
#   'Dell': 1,
#   'BlackBerry': 1,
#   'Android': 1,
#   'Microsoft Word': 1,
#   'PowerPoint': 1,
#   'Page’s Gmail': 1,
#   'Page': 2,
#   'Vinci': 1,
#   'Vincenzetti': 7,
#   'Tron': 1,
#   'the University of Milan': 1,
#   'The United Nations': 1,
#   'the Italian Parliament': 1,
#   'the European Union': 1,
#   'i. e.': 1,
#   'the University of Toronto’s Munk School of Global Affairs': 1,
#   'Peña Nieto’s': 1,
#   'Ernesto Aroche': 1,
#   'Puebla’s': 2,
#   'Aroche': 9,
#   'Sym Servicios Integrales': 2,
#   'Sagrario Conde Valerio': 1,
#   '‘Hacking Team': 1,
#   'The Hacked Team': 1,
#   'the Department of Justice': 2,
#   'the Royal Canadian Mounted Police': 1,
#   'Kleiner Perkins Caufield Byers': 1,
#   'the Harris Corporation': 1,
# ...
#   'Just last year': 1,
#   '’s final days': 1,
#   'several years ago': 1,
#   'more than 10 days': 1,
#   'Halloween': 1,
#   'the previous three years': 1,
#   'those final days': 1,
#   'nearly a century ago': 1,
#   'Last September': 1,
#   '2016 fiscal year': 2,
#   'Oct. 29': 1,
#   'Last spring': 1,
#   'late fall': 1,
#   'the end of the third year': 1,
#   'Nearly two years ago': 1,
#   'an uncertain year': 1,
#   'these days': 1,
#   'the fourth quarter of 2016': 1,
#   'the month of December': 1,
#   'the same month': 1,
#   'a year earlier': 1,
#   'the full year': 2,
#   'the month': 1,
#   'its first month': 1,
#   'the middle of 2016': 1,
#   '63': 1,
#   'the middle of 2017': 1},
#  'LAW': {'Constitution': 3,
#   'Precinct’s': 1,
#   'the Chinese Exclusion Act': 1,
#   'The Paris Agreement': 1,
#   'the Clean Air Task Force': 1,
#   'Louvre’s': 1,
#   'the Affordable Care Act': 12,
#   'Falcon 9': 1,
#   'the Fabulous Five': 1,
#   'the Betrayal of Democracy': 1,
#   'Obamas': 1,
#   'the Foreign Corrupt Practices Act': 1,
#   'the Grateful Dead': 1,
#   'Terminals 2 and 4': 1,
#   'the D. E. A.': 1,
#   'the Voting Rights Act': 1},
#  'LOC': {'The South Bronx': 1,
#   'the Harlem River': 1,
#   'the South Bronx': 3,
#   'the Lower East Side': 1,
#   'Lower East Side': 2,
#   'South Bronx': 1,
#   'East 151st Street': 1,
#   'the Bronx Cold Case Squad': 1,
#   'Rikers Island': 1,
#   'Angel Island': 1,
#   'the Ellis Island': 1,
#   'the West Coast': 2,
#   'Gold Mountain': 1,
#   'Ellis Island': 1,
#   'Southern California': 2,
#   'Earth': 3,
#   'Delta': 2,
#   'West Coast': 1,
#   'Silicon Valley': 3,
#   'North': 9,
#   'Pacific': 1,
#   'the east coast': 1,
#   'the west coast': 1,
#   'Africa': 3,
#   'Asia': 7,
#   'South China Sea': 1,
#   'Central America': 2,
#   'the Silver Lake': 1,
#   'SoHo': 1,
#   'Sahara': 1,
#   'the Gulf of Mexico': 1,
#   'Jupiter': 1,
#   'Shutterfly': 1,
#   'the Upper East Side': 3,
#   'Coney Island': 1,
#   'Northeast': 1,
#   'Sheepshead Bay': 2,
#   'Yarra River': 1,
#   'the Green Bay Packers': 1,
#   'Green Bay': 2,
#   'New England': 2,
#   'Europe': 10,
#   'the Middle East': 1,
#   'Central Asia': 2,
#   'Federal Plaza': 1,
#   'the Hindu Kush': 1,
#   'Cobras': 1,
#   'the Rae Kushner Yeshiva High School': 1,
#   'Staten Island': 1,
#   'Capitol Hill': 1,
#   'Make America': 1,
#   'South America': 2,
#   'Middle America': 2,
#   'the Hudson River': 1,
#   'the Bronx River Parkway': 1,
#   'Caribbean': 3,
#   'West': 3,
#   'Barada Valley': 1,
#   'the Barada Valley': 1,
#   'Grindstone Island': 1,
#   'West Dawson': 2,
#   'the Yukon River': 1,
#   'the Klondike River': 1,
#   'the Missisquoi Valley': 1,
#   'the Eastern Townships': 1,
#   'Mystic': 2,
#   'Lake Michigan': 1,
#   'South Florida': 1,
#   'the Peruvian Andes': 1,
#   'Lake Titicaca': 1,
#   'Mediterranean': 2,
#   'the Galápagos Islands': 1,
#   'Crystal Bach': 1,
#   'the Hill District': 1,
#   'Kew Gardens': 1,
#   'the South Pacific': 1,
#   'the South China Sea': 2,
#   'the Pacific Coast': 1,
#   'Middle East': 1,
#   'the China App Store': 1,
#   'the North Cotabato District Jail': 1,
#   'the North Cotabato District': 1,
#   'the Isle of Wight': 1,
#   'Condé Nast Editions': 1,
#   'Condé Nast': 1,
#   'Eastern Europe': 1,
#   'East Coast': 1,
#   'the D. N. C.': 2,
#   'the North Koreans': 1,
#   'Guantánamo Bay': 1},
#  'ORDINAL': {'40th': 24,
#   'second': 21,
#   'first': 129,
#   'third': 9,
#   'fifth': 2,
#   'First': 6,
#   '45th': 1,
#   '72nd': 1,
#   '11th': 1,
#   'sixth': 2,
#   'fourth': 6,
#   '50th': 1,
#   '83rd': 1,
#   'eighth': 1,
#   '150th': 2,
#   '12th': 1,
#   '175th': 1,
#   '375th': 1,
#   '15th': 1,
#   '58th': 1},
#  'PRODUCT': {'Precinct': 8,
#   '300s': 1,
#   'Otis': 1,
#   'Potomac': 1,
#   'the “Star Wars': 1,
#   'Starburst': 1,
#   'the Velvet Underground': 1,
#   'Nova': 2,
#   'Twitter': 37,
#   'Rodgers': 1,
#   'Cowboys': 2,
#   'Raiders': 1,
#   'Broncos': 1,
#   'Palmyra': 1,
#   'Concorde': 1,
#   'Mattis': 12,
#   'Joint Base Andrews': 1,
#   'the S. A. R.': 1,
#   'Roxane Gay’s': 1,
#   'Cruze': 1,
#   'Obamacare': 1,
#   'Shadow': 1,
#   'Aleppo': 2,
#   'MSC Seaside': 1,
#   'Terminal 5': 1,
#   'Alessandro Scarafile': 1,
#   'Harris’s Stingray': 1,
#   'Ocean Compass': 1,
#   'the C. I. A.': 2,
#   'the U. S. intelligence': 1,
#   'Coie': 1,
#   'A. P. T. 28': 1,
#   'LionTree': 1,
#   'Autodata': 1,
#   '200': 1},
#  'TIME': {'hours': 7,
#   '12 hours': 1,
#   'Around 6:30 each morning': 1,
#   '8 hours 35 minutes': 1,
#   '36 hours': 1,
#   'overnight': 5,
#   'evening': 2,
#   'at least nine hours': 1,
#   'seven hours': 1,
#   '45 minutes': 3,
#   'another 45 minutes': 1,
#   '40 minutes': 1,
#   'an hour': 3,
#   'midnight': 3,
#   'two to three hours': 1,
#   'December night': 1,
#   'that night': 1,
#   'Just minutes': 1,
#   'several hours': 1,
#   'night': 9,
#   'this morning': 1,
#   'each morning': 2,
#   'half an hour': 1,
#   'noon': 3,
#   'before noon': 1,
#   'morning': 17,
#   'About an hour earlier': 1,
#   'a few minutes': 1,
#   'only two hours': 1,
#   'Wednesday night': 2,
#   'the next morning': 1,
#   '1:05': 1,
#   'the opening seconds': 1,
#   'around 3 o’clock in the morning': 1,
#   '3 o’clock in the afternoon': 1,
#   'the early hours': 1,
#   'mornings': 1,
#   '50 minutes of each hour': 1,
#   'up to 10 hours': 1,
#   'just after midnight': 1,
#   'the first minutes': 1,
#   'three hours': 3,
#   'Monday evening': 1,
#   'afternoon': 5,
#   'the 10 hours': 1,
#   'the 12 hours': 1,
#   'eight hours': 1,
#   'about 17 hours': 1,
#   'about eight minutes': 1,
#   'between long hours': 1,
#   'a weeknight': 1,
#   '12 minutes': 1,
#   'One night': 1,
#   'a recent weeknight': 1,
#   'a triumphant morning': 1,
#   'midmorning': 1,
#   'less than 24 hours': 1,
#   'About an hour later': 1,
#   'Hours later': 1,
#   'early hours': 1,
#   'Tuesday night': 1,
#   'Hours': 1,
#   'about six minutes later': 1,
#   '11 minutes': 1,
#   'five minutes every hour': 2,
#   '30 minutes': 1,
#   'the six hours': 1,
#   'each hour': 1,
#   'five minutes': 1,
#   'six uninterrupted hours': 1,
#   'early afternoon': 1,
#   'daytime': 7,
#   'daytime hours': 1,
#   'nights': 2,
#   '90 minutes': 1,
#   'a recent afternoon': 2,
#   'This morning': 1,
#   'midday': 1,
#   'An hour': 1,
#   'Later in the day': 1,
#   'nearly six hours': 1,
#   'only 24 hours': 1,
#   'about 90 minutes': 1,
#   '20 hours': 1,
#   'Three minutes': 1,
#   'the night of June 17, 2015': 1,
#   'five hours': 1,
#   'November night': 1,
#   'one morning': 2,
#   'just a moment': 1,
#   'just over four hours': 1,
#   'the morning': 2,
#   'All morning': 1,
#   '50 an hour': 1,
#   'two hours and 40 minutes': 1,
#   'a night': 1,
#   'working hours': 1,
#   'more than an hour': 1,
#   'hour': 1,
#   'his many hours': 1},
#  'FAC': {'East 146th Street': 2,
#   'Fernandez': 1,
#   'Courtlandt Avenue': 1,
#   'Union Square': 2,
#   'Gramercy Park': 1,
#   'Police Headquarters': 1,
#   'Angel Island Immigration Station': 1,
#   'Woods': 1,
#   'Pearl Harbor': 1,
#   'Broadway': 19,
#   'the Center for Strategic and International Studies': 1,
#   'the U. S. A.': 1,
#   'Westchester Avenue': 1,
#   'the Oval Office': 2,
#   'the Global C. C. S. Institute': 1,
#   'Disneyland': 1,
#   'Camp David': 1,
#   'Camp David’s': 1,
#   'Second Avenue': 6,
#   '96th Street': 3,
#   'Lexington Avenue': 1,
#   'Hudson Yards': 1,
#   '72nd Street': 1,
#   '125th Street': 1,
#   'City Hall': 2,
#   '86th Street': 2,
#   'Dylann S. Roof’s': 1,
#   'Port Phillip': 1,
#   'Times Square': 6,
#   'the Grand Palais': 2,
#   'Merton Park Studios': 1,
#   'the U. S.': 5,
#   'Guantánamo Bay': 1,
#   'Camp Whitehorse': 1,
#   'the Situation Room': 1,
#   'Barack Obama': 1,
#   'the Battle of Wanat': 1,
#   'Bagram Air Base': 1,
#   'the Container Store': 1,
#   'Calgary International Airport': 1,
#   'Rio de Janeiro': 1,
#   'Launchpad 39A': 1,
#   'the Kennedy Space Center': 1,
#   'Camp Dovid': 1,
#   '42nd Street': 1,
#   'Capitol': 2,
#   'the U. S. and': 1,
#   'the U. S. Louisa Adams': 1,
#   'the White House': 3,
#   'the F. C. C.': 1,
#   'the Panzhihua Land and Resources Bureau': 1,
#   'the Horace Mann School': 1,
#   'the Golden Gate Bridge': 1,
#   'Belmont Road': 1,
#   'the S. E. C.': 2,
#   'Taksim Square': 1,
#   'Stanford Prison Experiment': 1,
#   'Pike River': 1,
#   'Schönbrunn Palace': 1,
#   'MSC Cruises': 1,
#   'Great Trail': 1,
#   'the Samuel J. Friedman Theater': 1,
#   'the Barrymore Theater': 1,
#   'La Guardia Airport': 1,
#   'La Guardia': 5,
#   'Long Island Rail Road': 1,
#   'Vincenzetti': 1,
#   'the C. I. A. ’s': 1,
#   'the R. C. S.': 1,
#   'Silk Road': 1,
#   'the App Store': 1,
#   'the Rockefeller Foundation': 1,
#   'the D. N. C.': 7,
#   'the D. N. C. ’s': 1,
#   'the D. N. C. the committee': 1,
#   'the D. N. C. Nor': 1,
#   'the F. B. I.': 1,
#   'the D. N. C. The F. B. I.': 1,
#   'the D. N. C. and Podesta': 1,
#   'the N. S. A.': 1,
#   'the C. I. A.': 1,
#   'Guantánamo': 1,
#   'the Long Island Rail Road': 3,
#   'the Marketplace Mall': 1,
#   'the Oakdale Mall': 1,
#   'the Preakness Shopping Center': 1},
#  'QUANTITY': {'only about two square miles': 1,
#   'more than 100 feet': 1,
#   'only 90 miles': 1,
#   '400 miles': 1,
#   '300 pounds': 1,
#   '239 pounds': 1,
#   'just 191 pounds': 1,
#   'more than 100 pounds': 2,
#   '295 pounds': 1,
#   'hundreds of pounds': 1,
#   '263 pounds': 1,
#   '20 pounds': 1,
#   '444 pounds': 1,
#   'nearly 30 pounds': 1,
#   '370 pounds': 1,
#   'nine miles': 1,
#   '191 pounds': 1,
#   '255 pounds': 1,
#   'two pounds': 1,
#   'five pounds': 1,
#   'about 30 miles': 1,
#   '240 megawatts': 1,
#   '700 megawatts': 1,
#   '6 million tons': 1,
#   '5 billion miles': 1,
#   'hundreds of feet': 1,
#   '81 miles': 1,
#   'about 300 barrels': 1,
#   '50 miles': 1,
#   '50 megawatt': 1,
#   'Three miles': 2,
#   '4 feet': 1,
#   '3 feet': 1,
#   '12 miles': 1,
#   'minus 340 degrees': 1,
#   '40 degrees': 1,
#   'Several miles': 1,
#   'less than two miles': 1,
#   'millions of square miles': 1,
#   '300 miles': 1,
#   'less than 60 miles': 1,
#   '200 meters': 1,
#   'nearly 75 acres': 1,
#   'half a mile': 1,
#   'more than 10 miles per hour': 1},
#  'PERCENT': {'67 percent': 1,
#   '76 percent': 1,
#   '54 percent': 1,
#   '42 percent': 1,
#   '31 percent': 2,
#   '71 percent': 1,
#   '63 percent': 2,
#   '62 percent': 1,
#   '57 percent': 2,
#   '40 percent': 3,
#   '5 percent': 4,
#   '90 percent': 1,
#   '20 percent': 1,
#   '50 percent': 2,
#   '86 percent': 1,
#   'only 60 percent': 1,
#   '27 to 28 percent': 1,
#   'more than 8 percent': 1,
#   'more than 50 percent': 1,
#   '140 percent': 1,
#   '100 percent': 1,
#   'about 7 percent': 2,
#   '9 percent': 1,
#   '3 percent': 3,
#   '6 percent': 2,
#   '22 percent': 2,
#   'Forty percent': 1,
#   '75 percent': 2,
#   'roughly 74 percent': 1,
#   '70 percent': 1,
#   '96 percent': 1,
#   '98 percent': 1,
#   'about 90 percent': 1,
#   '10 percent': 3,
#   'Two percent': 1,
#   '17 percent': 1,
#   'about 2 percent': 1,
#   '15 percent': 1,
#   'More than 70 percent': 1,
#   'at least 12 percent': 1,
#   'as much as 8 percent': 1,
#   'only 10 percent': 1,
#   'about 25 percent': 1,
#   'about 3 percent': 1,
#   '0. 4 percent': 1,
#   'nearly 17 percent': 1,
#   'about 12 percent': 1,
#   'less than 1 percent': 1,
#   '2 percent': 2,
#   '1 percent': 1,
#   'nearly 10 percent': 1},
#  'WORK_OF_ART': {'When de Blasio': 1,
#   '40th and PSA 7': 1,
#   'Bambi': 9,
#   'The Sands of Iwo Jima': 1,
#   'Rebel Without a Cause': 1,
#   'The Wild Bunch': 1,
#   'Water to Paper': 2,
#   'Tyrus': 3,
#   'Snow White': 1,
#   'Walt Disney': 1,
#   'Before the Animation Begins: The Art and Lives of Disney Inspirational Sketch Artists': 1,
#   'Olympic': 2,
#   'Russell': 1,
#   'Harry Potter': 1,
#   'Godfather': 1,
#   'Adventures of Superman': 1,
#   'Mister Ed': 1,
#   'The Man From U. N. C. L. E. ”': 1,
#   'The Patty Duke Show': 1,
#   'The Life and Times of Grizzly Adams': 1,
#   'The Brady Bunch': 1,
#   'Growing Pains': 1,
#   'Happy Days': 1,
#   'Mork  Mindy': 1,
#   'Laverne  Shirley': 1,
#   'ICBM': 1,
#   'The Queen': 1,
#   'The Biggest Loser': 3,
#   'These Days': 1,
#   'Girls': 2,
#   'Trainwreck': 1,
#   'New Girl': 1,
#   'Survivor’s Remorse': 1,
#   'Love Me Again': 1,
#   'Need Your Love So Bad': 1,
#   'BedBedBedBedBed': 1,
#   'Feynman Diagrams for All': 1,
#   'I’ve Been Let Down': 1,
#   'Christmas Card From a Hooker': 1,
#   'Once, With Feeling': 1,
#   'Pulitzer Prize': 1,
#   'Exelon Generation': 1,
#   'Sunset Boulevard': 1,
#   'Citizen Kane': 1,
#   'Morning Joe': 1,
#   'My Way': 1,
#   'Fiddler on the Roof': 1,
#   'It’s 5 o’clock': 2,
#   'Trump': 2,
#   'Today Mahatma Gandhi': 1,
#   'Fair': 1,
#   'Emotions': 1,
#   'Dick Clark’s': 2,
#   'In very rare instances': 1,
#   'Auld Lang Syne': 1,
#   'Eternal Sites: From Bamiyan to Palmyra': 1,
#   'History Begins': 1,
#   'Freedom! ’90': 3,
#   'Listen Without Prejudice Vol': 1,
#   'Freedom!': 2,
#   'Freedom': 5,
#   'Working Girl': 1,
#   'Vogue': 1,
#   'Truth or Dare': 1,
#   'Faith': 1,
#   'Open Your Heart': 1,
#   'The Professor': 1,
#   'I Can’t Drive 55': 1,
#   'Nobel Peace Prize': 1,
#   'Made in America': 1,
#   'Motherless Brooklyn': 3,
#   'The Fortress of Solitude': 3,
#   'A Gambler’s Anatomy': 1,
#   'The Warriors': 1,
#   'Jerks From Nowhere': 1,
#   'Apes in the Plan': 1,
#   'Gun, With Occasional Music': 1,
#   'the Affordable Care Act': 3,
#   '‘The White Tiger’': 1,
#   'Difficult Women': 1,
#   'Americanness': 1,
#   'The Apprentice': 1,
#   'Bridgegate': 1,
#   'Schumer': 1,
#   'Azaria’s': 1,
#   'Your Money': 1,
#   'The Kelly File': 2,
#   '60 Minutes': 7,
#   'CBS Sunday Morning': 1,
#   'Beyond the Tank': 1,
#   'Days of Our Lives': 1,
#   'The Ellen DeGeneres Show': 1,
#   'Steve Harvey': 1,
#   'Rock Center': 1,
#   'Sunday Night Football': 1,
#   'Dateline': 1,
#   'Outnumbered': 1,
#   'The Five': 1,
#   '“The Age of Reform': 1,
#   'God and Man at': 1,
#   'A Time for Choosing': 1,
#   'The Revolt of the Elites': 1,
#   'Twilight of the Elites': 1,
#   'A Gentleman’s Guide to Love and Murder': 1,
#   'Fall in Love': 1,
#   'Today is the day': 1,
#   'Sábado Gigante': 1,
#   'Step Up': 1,
#   'The Affordable Care Act': 1,
#   'Affordable Care Act': 1,
#   'earmarks': 1,
#   'Bible': 1,
#   'Tywanza Sanders': 1,
#   'America Chief Suspect': 1,
#   'Do Not Say We Have Nothing': 1,
#   'Walkaway': 1,
#   'Paris of the North': 1,
#   'How Festive the Ambulance': 1,
#   'The Sound of Living Things': 1,
#   'Summer Night Concert Schönbrunn': 1,
#   'Aida': 1,
#   'Another Brick': 1,
#   'The Wall': 1,
#   'The Humans': 2,
#   'The Piano Lesson': 1,
#   'Platonov': 1,
#   'How Are Things': 1,
#   'The Fever': 1,
#   'a Tony Award': 1,
#   'Jimmy Page': 1,
#   'B Side': 1,
#   'Going Dark': 1,
#   'Labor’s Love Lost: The Rise and Fall': 1,
#   'Reshaping the   Debate:': 1,
#   'White   ': 1,
#   'As long as bigger': 1,
#   'Ocean Medallion': 1,
#   'The Voyager with': 1,
#   'Titanic: The New Evidence': 1,
#   'A Night to Remember': 1,
#   '“The Irish Aboard Titanic': 1,
#   'Jersey Boys': 2,
#   'The Lion King': 2,
#   'Oh, Hello': 1,
#   'The Illusionists': 2,
#   'The Phantom of the Opera': 1,
#   'A Bronx Tale': 1,
#   'Dear Evan Hansen': 1,
#   'Matilda': 1,
#   'Taxi': 1,
#   'Alice': 1,
#   'Chico and the Man': 1,
#   'Laverne and Shirley': 1,
#   'All in the Family': 2,
#   'The Middle': 1,
#   'Deadliest Catch': 1,
#   'Fuller House': 1,
#   'Gilmore Girls': 1,
#   'Don’t Go Breaking My Heart': 1,
#   'The Mary Tyler Moore Show': 1,
#   'Six Feet Under': 1,
#   'The Ranch': 1,
#   'Roseanne': 1,
#   'Tears We Cannot Stop': 1,
#   'A Sermon to White America': 1,
#   'Around That Time:': 1,
#   'Purple Rain': 1,
#   'the Dukes': 2,
#   'Facebook': 1,
#   'Moonlight Maze  ': 1,
#   'cyber Pearl Harbor': 1,
#   'The D. N. C.': 1,
#   'False': 1,
#   'Shadow Brokers': 1,
#   'The Godfather': 1,
#   'Why American Elections Are Flawed': 1,
#   'The U. S.': 1,
#   'As the C. E. O. of MF Global': 1},
#  'EVENT': {'World Wars': 1,
#   'World War II': 2,
#   'the Vietnam War': 3,
#   'the Vietnam War’s': 1,
#   'New Year’s Day': 6,
#   'New Year’s': 8,
#   'the Communist Revolution of 1949': 1,
#   'Vietnam War': 1,
#   'the Paris Agreement': 1,
#   'New Year’s Eve': 8,
#   'the New Year': 1,
#   'Green Bay Packers': 1,
#   'the Super Bowl': 1,
#   'Super Bowl': 1,
#   'Olympics': 2,
#   'Corinne Day': 1,
#   'Falcon 9': 1,
#   'the New Year’s': 1,
#   'the Iraq war': 2,
#   'the Vietnam War  ': 1,
#   'the Westchester Summer Day': 1,
#   'Selection Day': 1,
#   'World Cup': 1,
#   'the 2018 World Cup': 1,
#   'New Year': 1,
#   'the American Revolution': 1,
#   'Dom Pérignon Rosé': 1,
#   'World War I': 1,
#   'the Revolutionary War': 1,
#   'the Salzburg Festival': 1,
#   'the       Joie de Vivre': 1,
#   'Hell Week': 1,
#   'the Arab Spring': 2,
#   'Vincenzetti': 1,
#   'the Ocean Medallion': 1,
#   'Ocean Medallion': 1,
#   'Watergate': 1,
#   'the Cold War days': 1,
#   'Inauguration Day': 1,
#   'the Civil War': 1},
#  'LANGUAGE': {'English': 3, 'Russian': 2}}

# %%
len(processed_docs)
# Out:
# 100

# %% [markdown]
# ### Better way to print the Entity Types and Values
#
# In this code, you print out the type of a named entity (e.g., ORG) and for each type, you extract all entities assigned with this type in the dictionary, sorted by their frequency in descending order.
#
# Print out the most frequent 10 entities per type

# %%
def print_top_10(named_entities):
    for key in named_entities.keys():        
        print(key)
        entities = named_entities.get(key)
                
        # Sort the entries by their frequency in descending 
        # order and print out the most frequent n ones
        sorted_keys = sorted(entities, key=entities.get, reverse=True )
        for item in sorted_keys[:10]:
            if (entities.get(item) > 1 ):
                print(" " + item + ": " + str(entities.get(item)))
                
print_top_10(named_entities)
# Out:
# GPE
#  the United States: 81
#  China: 61
#  Russia: 50
#  Washington: 48
#  Afghanistan: 42
#  Turkey: 40
#  New York: 38
#  America: 31
#  Manhattan: 30
#  Iraq: 28
# NORP
#  Republicans: 138
#  American: 136
#  Republican: 67
#  Democrats: 60
#  Russian: 59
#  Chinese: 48
#  Democratic: 31
#  Americans: 26
#  Russians: 24
#  Democrat: 23
# PERSON
#  Trump: 255
#  Obama: 114
#  Roof: 41
#  Kelly: 39
#  Donald J. Trump: 37
#  Wong: 31
#  Clinton: 30
#  Kerr: 27
#  Netanyahu: 25
#  Leahy: 24
# ORG
#  House: 84
#  Senate: 69
#  Congress: 68
#  Hacking Team: 35
#  the White House: 31
#  Times: 27
#  Apple: 25
#  Hacking Team’s: 24
#  Trump: 23
#  NBC: 20
# MONEY
#  1: 9
#  billions of dollars: 5
#  2: 5
#  3: 4
#  more than $1 billion: 3
#  the billions of dollars: 3
#  100: 3
#  millions of dollars: 3
#  tens of millions: 3
#  $5 million: 3
# CARDINAL
#  one: 122
#  two: 91
#  000: 53
#  three: 40
#  One: 34
#  Five: 24
#  2: 23
#  four: 21
#  1: 19
#  10: 14
# DATE
#  Wednesday: 50
#  Tuesday: 42
#  2015: 36
#  last year: 32
#  2016: 32
#  Sunday: 32
#  Thursday: 32
#  years: 30
#  this year: 29
#  Monday: 23
# LAW
#  the Affordable Care Act: 12
#  Constitution: 3
# LOC
#  Europe: 10
#  North: 9
#  Asia: 7
#  the South Bronx: 3
#  Earth: 3
#  Silicon Valley: 3
#  Africa: 3
#  the Upper East Side: 3
#  Caribbean: 3
#  West: 3
# ORDINAL
#  first: 129
#  40th: 24
#  second: 21
#  third: 9
#  First: 6
#  fourth: 6
#  fifth: 2
#  sixth: 2
#  150th: 2
# PRODUCT
#  Twitter: 37
#  Mattis: 12
#  Precinct: 8
#  Nova: 2
#  Cowboys: 2
#  Aleppo: 2
#  the C. I. A.: 2
# TIME
#  morning: 17
#  night: 9
#  hours: 7
#  daytime: 7
#  overnight: 5
#  afternoon: 5
#  45 minutes: 3
#  an hour: 3
#  midnight: 3
#  noon: 3
# FAC
#  Broadway: 19
#  the D. N. C.: 7
#  Second Avenue: 6
#  Times Square: 6
#  the U. S.: 5
#  La Guardia: 5
#  96th Street: 3
#  the White House: 3
#  the Long Island Rail Road: 3
#  East 146th Street: 2
# QUANTITY
#  more than 100 pounds: 2
#  Three miles: 2
# PERCENT
#  5 percent: 4
#  40 percent: 3
#  3 percent: 3
#  10 percent: 3
#  31 percent: 2
#  63 percent: 2
#  57 percent: 2
#  50 percent: 2
#  about 7 percent: 2
#  6 percent: 2
# WORK_OF_ART
#  Bambi: 9
#  60 Minutes: 7
#  Freedom: 5
#  Tyrus: 3
#  The Biggest Loser: 3
#  Freedom! ’90: 3
#  Motherless Brooklyn: 3
#  The Fortress of Solitude: 3
#  the Affordable Care Act: 3
#  Water to Paper: 2
# EVENT
#  New Year’s: 8
#  New Year’s Eve: 8
#  New Year’s Day: 6
#  the Vietnam War: 3
#  World War II: 2
#  Olympics: 2
#  the Iraq war: 2
#  the Arab Spring: 2
# LANGUAGE
#  English: 3
#  Russian: 2

# %%
named_entities.keys()
# Out:
# dict_keys(['GPE', 'NORP', 'PERSON', 'ORG', 'MONEY', 'CARDINAL', 'DATE', 'LAW', 'LOC', 'ORDINAL', 'PRODUCT', 'TIME', 'FAC', 'QUANTITY', 'PERCENT', 'WORK_OF_ART', 'EVENT', 'LANGUAGE'])

# %% [markdown]
# #### Interpretation of the above
#
# As this table shows, the most frequently used named entities in the news articles are entities of the following types: PERSON, GPE, ORG, and DATE. This is, perhaps, not very surprising: after all, most often news report on the events that are related to people (PERSON), companies (ORG), countries (GPE), and usually news articles include references to specific dates.
#
# ------------------------------
#
# # Extracting the subject (the entity that performs the action) or an object (an entity to which the action applies)
#
#
# ----------
#
# Suppose your named entity of interest is a multi-word expression **The New York Times**
#
# And the full sentence is **“The New York Times wrote about Apple”**.
#
# #### And from the above we know that indeed, The New York Times as a whole is the subject – it is the entity that performed the action of writing.
#
# ### So the problem is - How can you extract the whole expression "The New York Times?"
#
# ----------
#
# ### Overall Solution Approach
#
# 1. **So the first step of the solution is**, you first identify the indexes of the words covered by this expression in the sentence: for "The New York Times" these are [0, 1, 2, 3], as the left part.
#
#
# 2. Next, i.e. the second half of the task, you check if a word with any of these indexes plays a role of the subject or an object in the sentence.
#
# 3. And we see that, indeed, the word that is the subject in the sentence has the index of 3 .
#
# 4. Therefore, you can return the whole named entity "The New York Times" as the subject of the main action in the sentence.

# %%
def calculate_entity_span(document, entity):
    """
    Calculate the span of a named entity in a document.

    Args:
        document (spacy.tokens.Doc): The document to search for the entity.
        entity (str): The entity to find in the document.

    Returns:
        list: A list of indices representing the span of the entity in the document.
    """
    # Initialize a list to hold the indices
    indexes = []
    
    # Iterate over the entities in the document
    for ent in document.ents:
        # If the entity text matches the entity we're looking for...
        if ent.text == entity:
            # Iterate over the range from the entity's start to its end
            for i in range(int(ent.start), int(ent.end)):
                # Append the index to the list
                indexes.append(i)
                
    # Return the list of indices
    return indexes

# %%
entity = "The New York Times"

sentences = "The New York Times wrote about Apple"

doc = nlp(sentences)

calculate_entity_span(doc, entity)
# Out:
# [0, 1, 2, 3]

# %%
sentences = ["The New York Times wrote about Apple"]

for sentence in sentences:
    doc = nlp(sentence)
    for token in doc:
        print(token.dep_)
# Out:
# det
# compound
# compound
# nsubj
# ROOT
# prep
# pobj

# %%
def calc_entity_subject_object(document, entity, indexes):
    """
    Analyze a document to find actions related to a specific entity.

    Args:
        document (spacy.tokens.Doc): The document to analyze.
        entity (str): The entity to find actions for.
        indexes (list): A list of indices in the document where the entity appears.

    Returns:
        None: Prints out the sentence and all actions involving the entity.
    """
    actions = []
    action = ''
    participant1 = ''
    participant2 = ''
    
    for token in document:
        # Next, you identify the main verb expressing the main action in the sentence
        # To extract the relation, we have to find the ROOT of the sentence (which is also the verb of the sentence)
        if token.pos_ == "VERB" and token.dep_ == 'ROOT':
            # Initialize the indexes for the subject and the object related to the main verb
            subj_ind = -1
            obj_ind = -1
            # Store the main verb itself (token.text) in the action variable
            action = token.text
            children = [child for child in token.children ]
            for child1 in children:
                # Find the subject via the nsubj relation and store it as participant1 
                # and its index as subj_ind
                if child1.dep_ == 'nsubj':
                    participant1 = child1.text
                    subj_ind = int(child1.i)
                # If there is a preposition attached to the verb (e.g., “write about”), then
                # you need to search for the indirect object as the second participant. 
                if child1.dep_ == 'prep':
                    participant2 = ''
                    child1_children = [child for child in child1.children]
                    for child2 in child1_children:
                        # If such an object is a noun or a proper noun, 
                        # you store it as participant2 and its index as obj_ind
                        if child2.pos_ == 'NOUN' or child2.pos_ == 'PROPN':
                            participant2 = child2.text
                            obj_ind = int(child2.i)
                    
                    # If at this point both participants of the main action have been identified and
                    # their indexes are included in the indexes of the words covered by the entity, 
                    # you add the action with two participants to the list of actions.
                    if not participant2=="":
                        if subj_ind in indexes:
                            actions.append(entity + " " + action + " " + child1.text + " " + participant2)
                        elif obj_ind in indexes:
                            actions.append(participant1 + " " + action + " " + child1.text + " " + entity)
                            
                # Otherwise, if there is no preposition attached to the verb,
                # participant2 is a direct object of the main verb, 
                # which can be identified via the dobj relation
                if child1.dep_ == 'dobj' and (child1.pos_ == 'NOUN' or child1.pos_ == 'PROPN' ):
                    participant2 = child1.text
                    obj_ind = int(child1.i)
                    # In this case, you apply the same strategy as above, 
                    # adding the action with two participants to the list of actions. 
                    if subj_ind in indexes:
                         actions.append(entity + " " + action + " " + participant2)
                    elif obj_ind in indexes:
                        actions.append(participant1 + " " + action + " " + entity)
    # Finally if the final list of actions is not empty, 
    # Print out the sentence and all actions together with the participants.
    if not len(actions) == 0:
        print(f"\nSentence = {document}")
        for item in actions:
            print(item)

# %%
for sentence in sentences:
    doc = nlp(sentence)
    indexes = calculate_entity_span(doc, entity)
    calc_entity_subject_object(doc, entity, indexes)
# Out:
# Sentence = The New York Times wrote about Apple
# Times wrote about Apple

# %%
def return_docs_of_given_ent_type(processed_docs, entity, ent_type):
    """
    Extracts sentences from a list of processed documents that contain a given named entity of a specific type.

    Args:
        processed_docs (list): A list of processed documents. Each document is a spacy.tokens.Doc object.
        entity (str): The named entity to search for.
        ent_type (str): The type of the named entity (e.g. 'ORG', 'PERSON', 'GPE')

    Returns:
        output_sentences (list): A list of sentences containing the named entity of the specified type.
    """
    output_sentences = []
    for doc in processed_docs:
        for sentence in doc.sents:
            # Only consider sentences that contain the input entity 
            # of the specified type among its named entities
            if entity in [ent.text for ent in sentence.ents if ent.label_ == ent_type ]:
                output_sentences.append(sentence)
    return output_sentences

entity = "Apple"

ent_sentences = return_docs_of_given_ent_type(processed_docs, entity, 'ORG' )
print(ent_sentences)
# Out:
# [American tech giants like Google, Apple and Facebook are on a collision course with European regulators over issues including privacy and taxes., Nearly a year ago, I argued that we were witnessing a new era in the tech business, one that is typified less by the storied   in a garage than by a posse I like to call the Frightful Five: Amazon, Apple, Facebook, Microsoft and Alphabet, Google’s parent company., The precise nature of the fights varies by company and region, including the tax and antitrust investigations of Apple and Google in Europe and Donald J. Trump’s broad and often incoherent criticism of the Five for various alleged misdeeds., Apple’s sales were flat last year, and after a monster 2016, Alphabet’s stock price hit a plateau., When Apple took on the Federal Bureau of Investigation last year over access to a terrorist’s iPhone, many in tech sided with the company, but a majority of Americans thought Apple should give in., He promised to force Apple to make iPhones in America., In a 2014 address, now referred to in cybersecurity circles as his “Going Dark” speech, the F. B. I. ’s director, James Comey, argued that the encryption built into Apple products posed a threat to public safety  —   enabling not only terrorism but also drug trafficking, child abuse and   ., Apple, complying with what it said was a request from Chinese authorities, removed news apps created by The New York Times from its app store in China late last month., Apple removed both the   and   apps from the app store in China on Dec. 23., “For some time now the New York Times app has not been permitted to display content to most users in China and we have been informed that the app is in violation of local regulations,” Fred Sainz, an Apple spokesman, said of the Times apps., Mr. Sainz declined to comment on what local regulations the Times apps were said to have violated, who had contacted Apple and when, and whether a court order or other legal document had been presented., A Times spokeswoman in New York, Eileen Murphy, said the company had asked Apple to reconsider its decision., Apple has previously removed other, less prominent media apps from its China store., Apple’s chief executive, Timothy D. Cook, has said that the company complies with all local laws., While in early 2016 Apple resisted a court request in the United States for it to help federal officials unlock an iPhone for a criminal investigation, Mr. Cook said he would obey whatever order the court ultimately handed down., In the end, the government was able to unlock the device without Apple’’s help and the case was dropped., Farzana Aslam, associate director of the Center for Comparative and Public Law at the University of Hong Kong, noted that in matters involving customer privacy, Apple requires governments to submit subpoenas, search warrants or other legal documents., She added that it was “very worrying” that Apple had not disclosed what laws the authorities said were violated, making it difficult for The Times and other publishers to file an appeal or challenge the government’s requests., China is also one of Apple’s largest iPhone markets, though sales in that region have slowed., On Dec. 23, David Barboza, a Times reporter, spoke with members of Apple’s media team about the article., Later that day, a separate team from Apple informed The Times that the apps would be removed, Ms. Murphy said., The Times news apps remain available in Apple’s app stores for other countries, as well as the Hong Kong and Taiwan stores, but people must have a credit card with a billing address outside mainland China to download them., Apple’s decision to remove the app from its China store should not affect those who have already installed it., Mr. Natkin said that Apple had a certain amount of leverage against the Chinese government in terms of the total amount of jobs created but that “the technology gap has started to close. ”]

# %%
for sentence in ent_sentences:
    indexes = calculate_entity_span(sentence, entity)
    calc_entity_subject_object(sentence, entity, indexes)
# Out:
# Sentence = Apple, complying with what it said was a request from Chinese authorities, removed news apps created by The New York Times from its app store in China late last month.
# Apple removed apps
#
# Sentence = Apple removed both the   and   apps from the app store in China on Dec. 23.
# Apple removed from store
# Apple removed on Dec.
#
# Sentence = Apple has previously removed other, less prominent media apps from its China store.
# Apple removed apps
# Apple removed from store

# %%
entity = "The New York Times"

ent_sentences = return_docs_of_given_ent_type(processed_docs, entity, "ORG")
print(len(ent_sentences))

for sentence in ent_sentences:
    indexes = calculate_entity_span(sentence, entity)
    calc_entity_subject_object(sentence, entity, indexes)
# Out:
# 13
#
# Sentence = During negotiations with Mr. Corzine last year, the commission also strengthened aspects of the deal after some of the agency’s commissioners questioned it, The New York Times reported at the time.
# The New York Times reported at time

# %% [markdown]
# ## Apply visualization with displaCy

# %%
from spacy import displacy

text = "Last week, Democratic lawmakers from both parties said they had the Senate votes needed to pass legislation that would prevent tech platforms, including Apple, GM and Facebook, from favoring their own businesses."

doc = nlp(text)

displacy.render(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Last week
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Democratic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  lawmakers from both parties said they had the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Senate
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  votes needed to pass legislation that would prevent tech platforms, including
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     GM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Facebook
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , from favoring their own businesses.</div></span>

# %% [markdown]
# ## Visualize entity types in sentences containing the specified entity:

# %%
def visualize_given_ent_type(processed_docs, entity, ent_type):
    """
    Visualizes named entity annotations in sentences containing a given named entity of a specific type.

    Args:
        processed_docs (list): A list of processed documents. Each document is a spacy.tokens.Doc object.
        entity (str): The named entity to search for.
        ent_type (str): The type of the named entity (e.g. 'ORG', 'PERSON', 'GPE')

    Returns:
        None. Displays inline the named entity annotations for sentences containing the specified entity.
    """
    for doc in processed_docs:
        for sentence in doc.sents:
            if entity in [ent.text for ent in sentence.ents if ent.label_ == ent_type ]:
                displacy.render(sentence, style='ent' )

visualize_given_ent_type(processed_docs, 'Apple', 'ORG' )
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     American
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  tech giants like
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and Facebook are on a collision course with
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     European
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  regulators over issues including privacy and taxes. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nearly a year ago
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , I argued that we were witnessing a new era in the tech business, one that is typified less by the storied   in a garage than by a posse I like to call the Frightful
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Five
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# :
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amazon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Facebook
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Microsoft
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alphabet, Google’s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  parent company. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The precise nature of the fights varies by company and region, including the tax and antitrust investigations of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and Google in
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Europe
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Donald J. Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ’s broad and often incoherent criticism of the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Five
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  for various alleged misdeeds. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ’s sales were flat
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     last year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , and after a monster
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2016
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alphabet’s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  stock price hit a plateau. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">When
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  took on
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Federal Bureau of Investigation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     last year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  over access to a terrorist’s
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     iPhone
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , many in tech sided with the company, but a majority of
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Americans
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  thought
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  should give in. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">He promised to force
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  to make
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     iPhones
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     America
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">In a
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2014
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  address, now referred to in cybersecurity circles as his “
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Going Dark
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# ” speech, the F. B. I. ’s director,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     James Comey
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , argued that the encryption built into
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  products posed a threat to public safety  —   enabling not only terrorism but also drug trafficking, child abuse and   . </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , complying with what it said was a request from
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Chinese
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  authorities, removed news apps created by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The New York Times
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  from its app store in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     China
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     late last month
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  removed both the   and   apps from the app store in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     China
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dec. 23
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">“For some time now
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the New York Times
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  app has not been permitted to display content to most users in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     China
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and we have been informed that the app is in violation of local regulations,”
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Fred Sainz
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , an
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  spokesman, said of the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Times
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  apps. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sainz
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  declined to comment on what local regulations the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Times
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  apps were said to have violated, who had contacted
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and when, and whether a court order or other legal document had been presented. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">A
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Times
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  spokeswoman in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     New York
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Eileen Murphy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , said the company had asked
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  to reconsider its decision. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  has previously removed other, less prominent media apps from its
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     China
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  store. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ’s chief executive,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Timothy D. Cook
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , has said that the company complies with all local laws. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">While in early
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2016
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  resisted a court request in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the United States
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  for it to help federal officials unlock an
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     iPhone
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  for a criminal investigation, Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cook
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said he would obey whatever order the court ultimately handed down. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">In the end, the government was able to unlock the device without
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ’’s help and the case was dropped. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Farzana Aslam
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , associate director of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Center for Comparative and Public Law
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the University of Hong Kong
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , noted that in matters involving customer privacy,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  requires governments to submit subpoenas, search warrants or other legal documents. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">She added that it was “very worrying” that
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  had not disclosed what laws the authorities said were violated, making it difficult for The
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Times
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and other publishers to file an appeal or challenge the government’s requests. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     China
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  is also
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ’s largest
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     iPhone
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  markets, though sales in that region have slowed. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">On
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dec. 23
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     David Barboza
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , a
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Times
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  reporter, spoke with members of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ’s media team about the article. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Later that day
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , a separate team from
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  informed The
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Times
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  that the apps would be removed, Ms.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Murphy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Times
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  news apps remain available in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ’s app stores for other countries, as well as the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hong Kong
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Taiwan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  stores, but people must have a credit card with a billing address outside mainland
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     China
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  to download them. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ’s decision to remove the app from its
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     China
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  store should not affect those who have already installed it. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Natkin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said that
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  had a certain amount of leverage against the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Chinese
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  government in terms of the total amount of jobs created but that “the technology gap has started to close. ”</div></span>

# %% [markdown]
# ## Now - Find sentences where the particular named entity is used alongside other entities of the same type - i.e. a specific entity type is used a particular number of times

# %%
def return_count_of_ent_type(sentence, ent_type):
    return len([ent.text for ent in sentence.ents if ent.label_ == ent_type ])

txt = "Last week, Democratic lawmakers from both parties said they had the Senate votes needed to pass legislation that would prevent tech platforms, including Apple, GM and Facebook, from favoring their own businesses."

doc = nlp(txt)

return_count_of_ent_type(doc, 'ORG')
# Out:
# 4

# %%
def return_docs_of_given_ent_type_custom(processed_docs, entity, ent_type):
    """
    Returns sentences containing a given named entity of a specific type, 
    but only if there is more than one occurrence of the entity type in the sentence.

    Args:
        processed_docs (list): A list of processed documents. Each document is a spacy.tokens.Doc object.
        entity (str): The named entity to search for.
        ent_type (str): The type of the named entity (e.g. 'ORG', 'PERSON', 'GPE')

    Returns:
        output_sentences (list): A list of sentences that contain the specified entity 
                                 and have more than one occurrence of the specified entity type.
    """
    output_sentences = []
    for doc in processed_docs:
        for sentence in doc.sents:
            if entity in [ent.text for ent in sentence.ents if ent.label_ == ent_type and
                          return_count_of_ent_type(sentence, ent_type) > 1 ]:
                output_sentences.append(sentence)
    return output_sentences

output_sentences = return_docs_of_given_ent_type_custom(processed_docs, "Apple", "ORG")

print(len(output_sentences))
# Out:
# 16

# %%
def visualize_conditional_sentences(sentences):
    """
    This function visualizes the named entities in the given sentences using the displaCy visualizer from SpaCy.
    It specifically highlights organizations (ORG) in the sentences.

    Parameters:
    sentences (list): A list of sentences. Each sentence is expected to be a SpaCy Doc object with named entities.

    Returns:
    None. The function directly renders the visualization in the Jupyter notebook or other environment.
    """
    colors = {"ORG": "linear-gradient(90deg, #64B5F6, #E0F7FA)"}
    options = {"ents": ["ORG"], "colors": colors}
    
    for sentence in sentences:
        displacy.render(sentence, style="ent", options=options)
        


visualize_conditional_sentences(output_sentences )
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">American tech giants like
# <mark class="entity" style="background: linear-gradient(90deg, #64B5F6, #E0F7FA); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: linear-gradient(90deg, #64B5F6, #E0F7FA); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and Facebook are on a collision course with European regulators over issues including privacy and taxes. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Nearly a year ago, I argued that we were witnessing a new era in the tech business, one that is typified less by the storied   in a garage than by a posse I like to call the Frightful Five:
# <mark class="entity" style="background: linear-gradient(90deg, #64B5F6, #E0F7FA); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amazon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: linear-gradient(90deg, #64B5F6, #E0F7FA); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: linear-gradient(90deg, #64B5F6, #E0F7FA); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Facebook
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: linear-gradient(90deg, #64B5F6, #E0F7FA); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Microsoft
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and
# <mark class="entity" style="background: linear-gradient(90deg, #64B5F6, #E0F7FA); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alphabet, Google’s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  parent company. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: linear-gradient(90deg, #64B5F6, #E0F7FA); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ’s sales were flat last year, and after a monster 2016,
# <mark class="entity" style="background: linear-gradient(90deg, #64B5F6, #E0F7FA); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alphabet’s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  stock price hit a plateau. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">When
# <mark class="entity" style="background: linear-gradient(90deg, #64B5F6, #E0F7FA); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  took on
# <mark class="entity" style="background: linear-gradient(90deg, #64B5F6, #E0F7FA); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Federal Bureau of Investigation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  last year over access to a terrorist’s
# <mark class="entity" style="background: linear-gradient(90deg, #64B5F6, #E0F7FA); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     iPhone
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , many in tech sided with the company, but a majority of Americans thought
# <mark class="entity" style="background: linear-gradient(90deg, #64B5F6, #E0F7FA); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  should give in. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">He promised to force
# <mark class="entity" style="background: linear-gradient(90deg, #64B5F6, #E0F7FA); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  to make
# <mark class="entity" style="background: linear-gradient(90deg, #64B5F6, #E0F7FA); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     iPhones
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in America. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: linear-gradient(90deg, #64B5F6, #E0F7FA); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , complying with what it said was a request from Chinese authorities, removed news apps created by
# <mark class="entity" style="background: linear-gradient(90deg, #64B5F6, #E0F7FA); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The New York Times
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  from its app store in China late last month. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">“For some time now
# <mark class="entity" style="background: linear-gradient(90deg, #64B5F6, #E0F7FA); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the New York Times
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  app has not been permitted to display content to most users in China and we have been informed that the app is in violation of local regulations,” Fred Sainz, an
# <mark class="entity" style="background: linear-gradient(90deg, #64B5F6, #E0F7FA); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  spokesman, said of the
# <mark class="entity" style="background: linear-gradient(90deg, #64B5F6, #E0F7FA); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Times
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  apps. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Mr. Sainz declined to comment on what local regulations the
# <mark class="entity" style="background: linear-gradient(90deg, #64B5F6, #E0F7FA); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Times
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  apps were said to have violated, who had contacted
# <mark class="entity" style="background: linear-gradient(90deg, #64B5F6, #E0F7FA); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and when, and whether a court order or other legal document had been presented. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">A
# <mark class="entity" style="background: linear-gradient(90deg, #64B5F6, #E0F7FA); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Times
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  spokeswoman in New York, Eileen Murphy, said the company had asked
# <mark class="entity" style="background: linear-gradient(90deg, #64B5F6, #E0F7FA); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  to reconsider its decision. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">While in early 2016
# <mark class="entity" style="background: linear-gradient(90deg, #64B5F6, #E0F7FA); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  resisted a court request in the United States for it to help federal officials unlock an
# <mark class="entity" style="background: linear-gradient(90deg, #64B5F6, #E0F7FA); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     iPhone
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  for a criminal investigation, Mr. Cook said he would obey whatever order the court ultimately handed down. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Farzana Aslam, associate director of
# <mark class="entity" style="background: linear-gradient(90deg, #64B5F6, #E0F7FA); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Center for Comparative and Public Law
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  at
# <mark class="entity" style="background: linear-gradient(90deg, #64B5F6, #E0F7FA); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the University of Hong Kong
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , noted that in matters involving customer privacy,
# <mark class="entity" style="background: linear-gradient(90deg, #64B5F6, #E0F7FA); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  requires governments to submit subpoenas, search warrants or other legal documents. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">She added that it was “very worrying” that
# <mark class="entity" style="background: linear-gradient(90deg, #64B5F6, #E0F7FA); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  had not disclosed what laws the authorities said were violated, making it difficult for The
# <mark class="entity" style="background: linear-gradient(90deg, #64B5F6, #E0F7FA); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Times
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and other publishers to file an appeal or challenge the government’s requests. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">China is also one of
# <mark class="entity" style="background: linear-gradient(90deg, #64B5F6, #E0F7FA); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ’s largest
# <mark class="entity" style="background: linear-gradient(90deg, #64B5F6, #E0F7FA); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     iPhone
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  markets, though sales in that region have slowed. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">On Dec. 23, David Barboza, a
# <mark class="entity" style="background: linear-gradient(90deg, #64B5F6, #E0F7FA); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Times
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  reporter, spoke with members of
# <mark class="entity" style="background: linear-gradient(90deg, #64B5F6, #E0F7FA); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ’s media team about the article. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Later that day, a separate team from
# <mark class="entity" style="background: linear-gradient(90deg, #64B5F6, #E0F7FA); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  informed The
# <mark class="entity" style="background: linear-gradient(90deg, #64B5F6, #E0F7FA); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Times
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  that the apps would be removed, Ms. Murphy said. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The
# <mark class="entity" style="background: linear-gradient(90deg, #64B5F6, #E0F7FA); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Times
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  news apps remain available in
# <mark class="entity" style="background: linear-gradient(90deg, #64B5F6, #E0F7FA); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ’s app stores for other countries, as well as the Hong Kong and Taiwan stores, but people must have a credit card with a billing address outside mainland China to download them. </div></span>
